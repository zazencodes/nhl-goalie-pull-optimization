# %%
from IPython.display import HTML
HTML('<style>div.text_cell_render{font-size:130%;}</style>')
# %load_ext version_information
# %version_information pandas
# Out:
# Software versions
# Python 3.7.1 64bit [Clang 4.0.1 (tags/RELEASE_401/final)]
# IPython 7.2.0
# OS Darwin 18.2.0 x86_64 i386 64bit
# pandas 0.23.4
# Mon Apr 22 06:55:38 2019 PDT

# %% [markdown]
# # Goalie Pull Bayes Optimize
#
#  - Parse the goalie pull stats we need
#
# ### This script is for the current format: *2007/2008* and later

# %% [markdown]
# ## Parse HTML Stats Table

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import re
import datetime
import time
from collections import OrderedDict
import glob
from tqdm import tqdm_notebook
from colorama import Fore, Style

# %% [markdown]
# ### Helper functions

# %%
def is_int(x):
    try:
        int(x)
        return True
    except:
        return False

def parse_time(s):
    _s = s.copy()
    _s = _s.apply(lambda x:
        datetime.datetime.strptime(x.split(' ')[0], '%M:%S')
    )
    _s = _s.apply(lambda x:
        datetime.timedelta(
        hours=x.hour,
        minutes=x.minute,
        seconds=x.second,
        microseconds=x.microsecond
    ))
    return _s

def parse_team(s):
    _s = s.copy()
    _s = _s.str.split().apply(lambda x: x[0])
    return _s

def parse_date(s):
    _s = s.copy()
    
    # invalid parsing will be set as NaT
    _s = pd.to_datetime(_s, errors='coerce')

    '''
     _s = _s.apply(lambda x: (re.search(',(.*)', x.text.splitlines()[2])
                             .group(1)
                             .strip()))
     _s = _s.apply(lambda x: datetime.datetime\
                             .strptime(x.strip(), '%B %d, %Y'))
    '''
    
    return _s

def goalie_pull_timedelta(s1, s2):
    out = []
    for d1, d2 in zip(s1.values, s2.values):
        try:
            o = d1 - d2
        except:
            o = float('nan')
        out.append(o)
    return out

# %% [markdown]
# ### Main Functions

# %%
def get_game_df(
    soup,
    local_html=True,
) -> pd.DataFrame:
    '''
    Returns the parsed HTML stats table for some game and returns
    a DataFrame.
    
    local_html : bool
        Set True if using local HTML file. Otherwise set False
        for requested HTML from nhl.com
    '''

    if not local_html:
        raise NotImplementedError('Only local HTML supported')

    # Parse the main table
    data = []
    for row in soup.find_all('tr', {'class': 'evenColor'}):
        d = []
        for i, row_data in enumerate(row.find_all('td')):
            if 'class' in row_data.attrs:
                classes = ' '.join(row_data.attrs['class'])
                if 'bborder' not in classes:
                    continue
            else:
                continue

            if i == 3:
                # Parse the time
                row_data_text = ' '.join([str(s) for s in row_data.contents])

            elif i >= 6:
                # Parse the players on ice
                row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data.text.strip()))

            else:
                # Standard parse
                row_data_text = row_data.text.strip()
                
            d.append(row_data_text)

        if len(d) >= 8:
            data.append(d[:8])
    
    cols = ['#', 'per', 'type', 'time', 'event', 'description', 'visitor_on_ice', 'home_on_ice']
    df = pd.DataFrame(data, columns=cols)
    
    good_rows = df['#'].apply(is_int)
    df = df.loc[good_rows]
    df['#'] = df['#'].astype(int)
    df['per'] = df['per'].astype(int)
    df['time'] = parse_time(df['time'])
    df['team'] = parse_team(df['description'])
    
    # Get the team info
    team_names = []
    for row_data in soup.find_all('td', {'class': 'heading + bborder'}):
        if 'on ice' in row_data.text.lower():
            team_names.append(row_data.text.split()[0])
        if len(team_names) == 2:
            break
    if len(team_names) != 2:
        team_names = ['', '']
    team_info = {'visitor': team_names[0], 'home': team_names[1]}
    
    return df, team_info

# %%
def goalie_pull_game_search(
    game_df: pd.DataFrame,
    team_info: dict,
    verbose=False,
) -> list:
    '''
    Search through a DataFrame stats table for goalie pulls, and
    finds empty net goals / games that end with a goalie pulled.
    
    team_info : dict
        Visitor and away team names.
    '''
    out = []
    pull_threshold = datetime.timedelta(minutes=15)

    o = {}
    prev_row = None
    prev_row_players = ['', '']
    pull_team = ''
    pull_switch = False
    goal_switch = False
    
    i_final_row = game_df.index[-1]

    for i, row in game_df.iterrows():
        if verbose:
            print(f'Looking at row {i}, # = {row["#"]}')
        if prev_row is None:
            prev_row = row.copy()
                 
        visitor_g_pull = 'G' not in row.visitor_on_ice
        home_g_pull = 'G' not in row.home_on_ice
        if visitor_g_pull or home_g_pull:
            if not pull_switch:
                # The goalie was just pulled
                pull_switch = True
                o = {}
                if visitor_g_pull:
                    pull_team = 'visitor'
                elif home_g_pull:
                    pull_team = 'home'
                else:
                    raise ValueError('Home or away team must have goalie pulled')
                o['team_name'] = team_info.get(pull_team, '')
                o['pull_period'] = row.per
                o['pull_time'] = (row.time + prev_row.time) / 2
                if verbose:
                    print(f'team, period, time = \n{o}')

        if i == i_final_row:
            # Check if game ended 5 on 6
            if o:
                print(Fore.RED + f'Game end with no goalie in net!' + Style.RESET_ALL)
                o['game_end_time'] = row.time
                out.append(o.copy())
                  
        # Search for an event (goal for / against / end of game)
        if pull_switch:
            print('Searching for a goal or end of game')
            if row.event.lower() == 'goal':
                print(f'Found goal after a pull, setting goal against time as {row.time}')
                if row.team == o['team_name']:
                    o['goal_for_time'] = row.time
                else:
                    o['goal_against_time'] = row.time
                  
                if row.time == o['pull_time']:
                    print(f'Goal time equal to pull time {row.time}. '
                          'Ignoring it and searching again.')
                    continue
                
                if ((pull_team == 'visitor' and visitor_g_pull)
                    or (pull_team == 'home' and home_g_pull)):
                    # It's a true empty net goal
                    print(Fore.RED + f'Found empty net goal:\n{o}' + Style.RESET_ALL)
                    out.append(o.copy())
                else:
                    print('Goalie was back in the net')
                    pass
                o = {}
                pull_switch = False

        prev_row = row.copy()

    return out


def get_game_meta(soup) -> dict:
    '''
    Get game metadata like the date and game number.
    '''
    try:
        center_el = soup.find_all('table', {'id': 'GameInfo'})[0]
        game_number = center_el.find_all('tr')[6].text.split()[-1].lstrip('0')
        date = center_el.find_all('tr')[3].text.strip()
        return {'game_number': game_number, 'date': date}
    except:
        print('Failed to get meta data :(')
        return {}

# %%
def parse_game(
    soup: BeautifulSoup,
    cols: list = None,
    season='',
    verbose=False
) -> list:
    '''
    Search for empty net goals for, against and game ends,
    for a given game. Input the HTML as a BeautifulSoup object.
    '''
    out = []
                  
    # Default columns
    if cols is None:
        cols = [
            'season',
            'game_number',
            'team_name',
            'date',
            'pull_period',
            'pull_time',
            'goal_for_time',
            'goal_against_time',
            'game_end_time',
            'goal_for_timedelta',
            'goal_against_timedelta',
            'game_end_timedelta',
        ]

    # Get the game stats df    
    game_df, team_info = get_game_df(soup)
    
    # Get the game metadata
    meta_data = get_game_meta(soup)
    if season:
        meta_data['season'] = season
                  
    # Check for goalie pulls
    visitor_goalie_pull_idx = ~(game_df.visitor_on_ice.str.contains('G'))
    home_goalie_pull_idx = ~(game_df.home_on_ice.str.contains('G'))
    if not (visitor_goalie_pull_idx.sum() + home_goalie_pull_idx.sum()):
        return []    
    
    # For each goalie pull, determine the outcome
    game_5on6_data = goalie_pull_game_search(
        game_df, team_info, verbose=verbose
    )
    
    if not game_5on6_data:
        return []
    
    out = []
    for row in game_5on6_data:
        row.update(meta_data)
        out.append([row.get(col, float('nan')) for col in cols])

    return out


def make_final_df(
    data: list,
    cols: list,
) -> pd.DataFrame:
    '''
    Return table with columns:
     - season
     - game number
     - team name
     - date
     - period of pull
     - time of pull
     - time of goal for
     - time of goal against
     - time of goal end
     - timedelta of goal for (since pull)
     - timedelta of goal against (since pull)
     - timedelta of game end (since pull)
     
    Each row represents a goalie pull event.
    Goalie pull events that don't result in
    one of the above are ignored.
    '''
    df = pd.DataFrame(data, columns=cols)
    df['date'] = parse_date(df.date.fillna('').astype(str))
    df['goal_for_timedelta'] = goalie_pull_timedelta(df.goal_for_time, df.pull_time)
    df['goal_against_timedelta'] = goalie_pull_timedelta(df.goal_against_time, df.pull_time)
    df['game_end_timedelta'] = goalie_pull_timedelta(df.game_end_time, df.pull_time)
    
    return df

# %%
def parse_game_range(
    seasons: list,
    test: bool = False,
) -> pd.DataFrame:
    '''
    Parse every game for a given season.
    
    Folder structure is:
    ../data/raw/html/{season}/{game_number}.html
    
    '''
    
    root_data_path = '../../data/raw/html'
    if not os.path.exists(root_data_path):
        print(f'Root data path not found ({root_data_path})')
        return None
    
    cols = [
        'season',
        'game_number',
        'team_name',
        'date',
        'pull_period',
        'pull_time',
        'goal_for_time',
        'goal_against_time',
        'game_end_time',
        'goal_for_timedelta',
        'goal_against_timedelta',
        'game_end_timedelta',
    ]    
    data = []
    for season in seasons:        
        search_string = os.path.join(root_data_path, season, '*.html')
        html_files = glob.glob(search_string)
        print(f'Found {len(html_files)} files')
        i = 0
        for file in tqdm_notebook(html_files):
            i += 1
            if test:
                return_condition = i%20 == 0
                if return_condition: 
                    print(f'Testing mode - stopping script at {return_condition}')
                    return data, make_final_df(data, cols)
            
            print(f'Processing file {file}')
            try:
                with open(file, 'r') as f:
                    page_text = f.read()
                    soup = BeautifulSoup(page_text, 'lxml')
            except Exception as e:
                print(f'Unable to read/parse file {file}')
                print(str(e))
                continue
            
            try:
                d = parse_game(soup, cols, season)
                if not d:
                    continue
            except Exception as e:
                print(f'Unable to parse game for file {file}')
                print(str(e))
                continue

            data += d
            
    df = make_final_df(data, cols)
    return df

# %%
def test_parse_game_range(season, game_number):
    '''
    Parse a specific game with verbose output.
    '''
    
    cols = [
        'season',
        'game_number',
        'team_name',
        'date',
        'pull_period',
        'pull_time',
        'goal_for_time',
        'goal_against_time',
        'game_end_time',
        'goal_for_timedelta',
        'goal_against_timedelta',
        'game_end_timedelta',
    ]    
    data = []
    
    file = f'../../data/raw/html/{season}/{game_number}.html'
    print(f'Processing file {file}')
    with open(file, 'r') as f:
        try:
            page_text = f.read()
            soup = BeautifulSoup(page_text, 'lxml')
        except Exception as e:
            print(f'Unable to read/parse file {file}')
            raise e

    try:
        d = parse_game(soup, cols, season, verbose=True)
        if not d:
            print('No return from parse_game')
    except Exception as e:
        print(f'Unable to parse game for file {file}')
        raise e

    data = d
    df = make_final_df(data, cols)
    return df

# %%
test_parse_game_range('20072008', 980)
# Out:
# Processing file ../../data/raw/html/20072008/980.html
# Looking at row 0, # = 1
# Looking at row 1, # = 2
# Looking at row 2, # = 3
# Looking at row 3, # = 4
# Looking at row 4, # = 5
# Looking at row 5, # = 6
# Looking at row 6, # = 7
# Looking at row 7, # = 8
# Looking at row 8, # = 9
# Looking at row 9, # = 10
# Looking at row 10, # = 11
# Looking at row 11, # = 12
# Looking at row 12, # = 13
# Looking at row 13, # = 14
# Looking at row 14, # = 15
# Looking at row 15, # = 16
# Looking at row 16, # = 17
# Looking at row 17, # = 18
# Looking at row 18, # = 19
# Looking at row 19, # = 20
# Looking at row 20, # = 21
# Looking at row 21, # = 22
# Looking at row 22, # = 23
# Looking at row 23, # = 24
# Looking at row 24, # = 25
# Looking at row 25, # = 26
# Looking at row 26, # = 27
# Looking at row 27, # = 28
# Looking at row 28, # = 29
# Looking at row 29, # = 30
# Looking at row 30, # = 31
# Looking at row 31, # = 32
# Looking at row 32, # = 33
# Looking at row 33, # = 34
# Looking at row 34, # = 35
# Looking at row 35, # = 36
# Looking at row 36, # = 37
# Looking at row 37, # = 38
# Looking at row 38, # = 39
# Looking at row 39, # = 40
# Looking at row 40, # = 41
# Looking at row 41, # = 42
# Looking at row 42, # = 43
# Looking at row 43, # = 44
# Looking at row 44, # = 45
# Looking at row 45, # = 46
# Looking at row 46, # = 47
# Looking at row 47, # = 48
# Looking at row 48, # = 49
# Looking at row 49, # = 50
# Looking at row 50, # = 51
# Looking at row 51, # = 52
# Looking at row 52, # = 53
# Looking at row 53, # = 54
# Looking at row 54, # = 55
# Looking at row 55, # = 56
# Looking at row 56, # = 57
# Looking at row 57, # = 58
# Looking at row 58, # = 59
# Looking at row 59, # = 60
# Looking at row 60, # = 61
# Looking at row 61, # = 62
# Looking at row 62, # = 63
# Looking at row 63, # = 64
# Looking at row 64, # = 65
# Looking at row 65, # = 66
# Looking at row 66, # = 67
# Looking at row 67, # = 68
# Looking at row 68, # = 69
# Looking at row 69, # = 70
# Looking at row 70, # = 71
# Looking at row 71, # = 72
# Looking at row 72, # = 73
# Looking at row 73, # = 74
# Looking at row 74, # = 75
# Looking at row 75, # = 76
# Looking at row 76, # = 77
# Looking at row 77, # = 78
# Looking at row 78, # = 79
# Looking at row 79, # = 80
# Looking at row 80, # = 81
# Looking at row 81, # = 82
# Looking at row 82, # = 83
# Looking at row 83, # = 84
# Looking at row 84, # = 85
# Looking at row 85, # = 86
# Looking at row 86, # = 87
# Looking at row 87, # = 88
# Looking at row 88, # = 89
# Looking at row 89, # = 90
# Looking at row 90, # = 91
# Looking at row 91, # = 92
# Looking at row 92, # = 93
# Looking at row 93, # = 94
# Looking at row 94, # = 95
# Looking at row 95, # = 96
# Looking at row 96, # = 97
# Looking at row 97, # = 98
# Looking at row 98, # = 99
# Looking at row 99, # = 100
# Looking at row 100, # = 101
# Looking at row 101, # = 102
# Looking at row 102, # = 103
# Looking at row 103, # = 104
# Looking at row 104, # = 105
# Looking at row 105, # = 106
# Looking at row 106, # = 107
# Looking at row 107, # = 108
# Looking at row 108, # = 109
# Looking at row 109, # = 110
# Looking at row 110, # = 111
# Looking at row 111, # = 112
# Looking at row 112, # = 113
# team, period, time =
# {'team_name': 'PIT', 'pull_period': 2, 'pull_time': Timedelta('0 days 00:10:00')}
# Searching for a goal or end of game
# Looking at row 113, # = 114
# Searching for a goal or end of game
# Looking at row 114, # = 115
# Searching for a goal or end of game
# Looking at row 115, # = 116
# Searching for a goal or end of game
# Looking at row 116, # = 117
# Searching for a goal or end of game
# Looking at row 117, # = 118
# Searching for a goal or end of game
# Looking at row 118, # = 119
# Searching for a goal or end of game
# Looking at row 119, # = 120
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:01:30
# Goalie was back in the net
# Looking at row 120, # = 121
# Looking at row 121, # = 122
# Looking at row 122, # = 123
# Looking at row 123, # = 124
# Looking at row 124, # = 125
# Looking at row 125, # = 126
# Looking at row 126, # = 127
# Looking at row 127, # = 128
# Looking at row 128, # = 129
# Looking at row 129, # = 130
# Looking at row 130, # = 131
# Looking at row 131, # = 132
# Looking at row 132, # = 133
# Looking at row 133, # = 134
# Looking at row 134, # = 135
# Looking at row 135, # = 136
# Looking at row 136, # = 137
# Looking at row 137, # = 138
# Looking at row 138, # = 139
# Looking at row 139, # = 140
# Looking at row 140, # = 141
# Looking at row 141, # = 142
# Looking at row 142, # = 143
# Looking at row 143, # = 144
# Looking at row 144, # = 145
# Looking at row 145, # = 146
# Looking at row 146, # = 147
# Looking at row 147, # = 148
# Looking at row 148, # = 149
# Looking at row 149, # = 150
# Looking at row 150, # = 151
# Looking at row 151, # = 152
# Looking at row 152, # = 153
# Looking at row 153, # = 154
# Looking at row 154, # = 155
# Looking at row 155, # = 156
# Looking at row 156, # = 157
# Looking at row 157, # = 158
# Looking at row 158, # = 159
# Looking at row 159, # = 160
# Looking at row 160, # = 161
# Looking at row 161, # = 162
# Looking at row 162, # = 163
# Looking at row 163, # = 164
# Looking at row 164, # = 165
# Looking at row 165, # = 166
# Looking at row 166, # = 167
# Looking at row 167, # = 168
# Looking at row 168, # = 169
# Looking at row 169, # = 170
# Looking at row 170, # = 171
# Looking at row 171, # = 172
# Looking at row 172, # = 173
# Looking at row 173, # = 174
# Looking at row 174, # = 175
# Looking at row 175, # = 176
# Looking at row 176, # = 177
# Looking at row 177, # = 178
# Looking at row 178, # = 179
# Looking at row 179, # = 180
# Looking at row 180, # = 181
# Looking at row 181, # = 182
# Looking at row 182, # = 183
# Looking at row 183, # = 184
# Looking at row 184, # = 185
# Looking at row 185, # = 186
# Looking at row 186, # = 187
# Looking at row 187, # = 188
# Looking at row 188, # = 189
# Looking at row 189, # = 190
# Looking at row 190, # = 191
# Looking at row 191, # = 192
# Looking at row 192, # = 193
# Looking at row 193, # = 194
# Looking at row 194, # = 195
# Looking at row 195, # = 196
# Looking at row 196, # = 197
# Looking at row 197, # = 198
# Looking at row 198, # = 199
# Looking at row 199, # = 200
# Looking at row 200, # = 201
# Looking at row 201, # = 202
# Looking at row 202, # = 203
# Looking at row 203, # = 204
# Looking at row 204, # = 205
# Looking at row 205, # = 206
# Looking at row 206, # = 207
# Looking at row 207, # = 208
# Looking at row 208, # = 209
# Looking at row 209, # = 210
# Looking at row 210, # = 211
# Looking at row 211, # = 212
# Looking at row 212, # = 213
# Looking at row 213, # = 214
# Looking at row 214, # = 215
# Looking at row 215, # = 216
# Looking at row 216, # = 217
# Looking at row 217, # = 218
# Looking at row 218, # = 219
# Looking at row 219, # = 220
# Looking at row 220, # = 221
# Looking at row 221, # = 222
# Looking at row 222, # = 223
# Looking at row 223, # = 224
# Looking at row 224, # = 225
# Looking at row 225, # = 226
# Looking at row 226, # = 227
# Looking at row 227, # = 228
# Looking at row 228, # = 229
# Looking at row 229, # = 230
# Looking at row 230, # = 231
# Looking at row 231, # = 232
# Looking at row 232, # = 233
# Looking at row 233, # = 234
# Looking at row 234, # = 235
# Looking at row 235, # = 236
# Looking at row 236, # = 237
# Looking at row 237, # = 238
# Looking at row 238, # = 239
# Looking at row 239, # = 240
# Looking at row 240, # = 241
# Looking at row 241, # = 242
# Looking at row 242, # = 243
# Looking at row 243, # = 244
# Looking at row 244, # = 245
# Looking at row 245, # = 246
# Looking at row 246, # = 247
# Looking at row 247, # = 248
# Looking at row 248, # = 249
# Looking at row 249, # = 250
# Looking at row 250, # = 251
# Looking at row 251, # = 252
# Looking at row 252, # = 253
# Looking at row 253, # = 254
# Looking at row 254, # = 255
# Looking at row 255, # = 256
# Looking at row 256, # = 257
# Looking at row 257, # = 258
# Looking at row 258, # = 259
# Looking at row 259, # = 260
# Looking at row 260, # = 261
# Looking at row 261, # = 262
# Looking at row 262, # = 263
# Looking at row 263, # = 264
# Looking at row 264, # = 265
# team, period, time =
# {'team_name': 'OTT', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:09:36')}
# Searching for a goal or end of game
# Looking at row 265, # = 266
# Searching for a goal or end of game
# Looking at row 266, # = 267
# Searching for a goal or end of game
# Looking at row 267, # = 268
# Searching for a goal or end of game
# Looking at row 268, # = 269
# Searching for a goal or end of game
# Looking at row 269, # = 270
# Searching for a goal or end of game
# Looking at row 270, # = 271
# Searching for a goal or end of game
# Looking at row 271, # = 272
# Searching for a goal or end of game
# Looking at row 272, # = 273
# Searching for a goal or end of game
# Looking at row 273, # = 274
# Searching for a goal or end of game
# Looking at row 274, # = 275
# Searching for a goal or end of game
# Looking at row 275, # = 276
# Searching for a goal or end of game
# Looking at row 276, # = 277
# Searching for a goal or end of game
# Looking at row 277, # = 278
# Searching for a goal or end of game
# Looking at row 278, # = 279
# Searching for a goal or end of game
# Looking at row 279, # = 280
# Searching for a goal or end of game
# Looking at row 280, # = 281
# Searching for a goal or end of game
# Looking at row 281, # = 282
# Searching for a goal or end of game
# Looking at row 282, # = 283
# Searching for a goal or end of game
# Looking at row 283, # = 284
# Searching for a goal or end of game
# Looking at row 284, # = 285
# Searching for a goal or end of game
# Looking at row 285, # = 286
# Searching for a goal or end of game
# Looking at row 286, # = 287
# Searching for a goal or end of game
# Looking at row 287, # = 288
# Searching for a goal or end of game
# Looking at row 288, # = 289
# Searching for a goal or end of game
# Looking at row 289, # = 290
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:14:06
# Goalie was back in the net
# Looking at row 290, # = 291
# Looking at row 291, # = 292
# Looking at row 292, # = 293
# Looking at row 293, # = 294
# Looking at row 294, # = 295
# Looking at row 295, # = 296
# Looking at row 296, # = 297
# Looking at row 297, # = 298
# Looking at row 298, # = 299
# Looking at row 299, # = 300
# Looking at row 300, # = 301
# Looking at row 301, # = 302
# Looking at row 302, # = 303
# Looking at row 303, # = 304
# Looking at row 304, # = 305
# Looking at row 305, # = 306
# Looking at row 306, # = 307
# Looking at row 307, # = 308
# Looking at row 308, # = 309
# Looking at row 309, # = 310
# Looking at row 310, # = 311
# Looking at row 311, # = 312
# Looking at row 312, # = 313
# Looking at row 313, # = 314
# Looking at row 314, # = 315
# Looking at row 315, # = 316
# Looking at row 316, # = 317
# team, period, time =
# {'team_name': 'PIT', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:56')}
# Searching for a goal or end of game
# Looking at row 317, # = 318
# Searching for a goal or end of game
# Looking at row 318, # = 319
# Searching for a goal or end of game
# Looking at row 319, # = 320
# Searching for a goal or end of game
# Looking at row 320, # = 321
# Searching for a goal or end of game
# Looking at row 321, # = 322
# Searching for a goal or end of game
# Looking at row 322, # = 323
# Searching for a goal or end of game
# Looking at row 323, # = 324
# Searching for a goal or end of game
# Looking at row 324, # = 325
# Searching for a goal or end of game
# Looking at row 325, # = 326
# Game end with no goalie in net!
# Searching for a goal or end of game
#      season game_number team_name       date  pull_period pull_time  \
# 0  20072008         980       PIT 2008-03-01            3  00:18:56
#
#    goal_for_time  goal_against_time game_end_time  goal_for_timedelta  \
# 0            NaN                NaN      00:20:00                 NaN
#
#    goal_against_timedelta game_end_timedelta
# 0                     NaN           00:01:04

# %%
seasons = ['20072008']

data, df_goalie_pull = parse_game_range(seasons, test=True)
# Out:
# Found 1230 files
# HBox(children=(IntProgress(value=0, max=1230), HTML(value='')))
# Processing file ../../data/raw/html/20072008/340.html
# Processing file ../../data/raw/html/20072008/710.html
# Processing file ../../data/raw/html/20072008/205.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:38
# Found empty net goal:
# {'team_name': 'BUF', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:45'), 'goal_against_time': Timedelta('0 days 00:19:38')}
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1230.html
# Processing file ../../data/raw/html/20072008/655.html
# Processing file ../../data/raw/html/20072008/985.html
# Processing file ../../data/raw/html/20072008/74.html
# Processing file ../../data/raw/html/20072008/1119.html
# Processing file ../../data/raw/html/20072008/439.html
# Processing file ../../data/raw/html/20072008/593.html
# Processing file ../../data/raw/html/20072008/747.html
# Processing file ../../data/raw/html/20072008/317.html
# Processing file ../../data/raw/html/20072008/602.html
# Processing file ../../data/raw/html/20072008/252.html
# Processing file ../../data/raw/html/20072008/481.html
# Processing file ../../data/raw/html/20072008/878.html
# Processing file ../../data/raw/html/20072008/23.html
# Unable to parse game for file ../../data/raw/html/20072008/23.html
# list index out of range
# Processing file ../../data/raw/html/20072008/897.html
# Processing file ../../data/raw/html/20072008/194.html
# Testing mode - stopping script at True

# %%
df_goalie_pull
# Out:
#      season game_number team_name       date  pull_period pull_time  \
# 0  20072008         205       BUF 2007-11-05            3  00:18:45
# 1  20072008         205       BUF 2007-11-05            3  00:19:38
#
#    goal_for_time goal_against_time game_end_time  goal_for_timedelta  \
# 0            NaN          00:19:38           NaT                 NaN
# 1            NaN               NaT      00:20:00                 NaN
#
#   goal_against_timedelta game_end_timedelta
# 0               00:00:53                NaT
# 1                    NaT           00:00:22

# %%
seasons = ['20072008', '20082009', '20092010',
           '20102011', '20112012', '20122013',
           '20132014', '20142015', '20152016',
          '20162017', '20172018']

dfs = []
for season in seasons:
    df_goalie_pull = parse_game_range([season])
    dfs.append(df_goalie_pull)
    df_goalie_pull.to_csv('../../data/processed/csv/{}_goalie_pulls_2019-04-22.csv'.format(season),
                          index=False)
    df_goalie_pull.to_pickle('../../data/processed/pkl/{}_goalie_pulls_2019-04-22.pkl'.format(season))
# Out:
# Found 1230 files
# HBox(children=(IntProgress(value=0, max=1230), HTML(value='')))
# Processing file ../../data/raw/html/20072008/340.html
# Processing file ../../data/raw/html/20072008/710.html
# Processing file ../../data/raw/html/20072008/205.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:38
# Found empty net goal:
# {'team_name': 'BUF', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:45'), 'goal_against_time': Timedelta('0 days 00:19:38')}
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1230.html
# Processing file ../../data/raw/html/20072008/655.html
# Processing file ../../data/raw/html/20072008/985.html
# Processing file ../../data/raw/html/20072008/74.html
# Processing file ../../data/raw/html/20072008/1119.html
# Processing file ../../data/raw/html/20072008/439.html
# Processing file ../../data/raw/html/20072008/593.html
# Processing file ../../data/raw/html/20072008/747.html
# Processing file ../../data/raw/html/20072008/317.html
# Processing file ../../data/raw/html/20072008/602.html
# Processing file ../../data/raw/html/20072008/252.html
# Processing file ../../data/raw/html/20072008/481.html
# Processing file ../../data/raw/html/20072008/878.html
# Processing file ../../data/raw/html/20072008/23.html
# Unable to parse game for file ../../data/raw/html/20072008/23.html
# list index out of range
# Processing file ../../data/raw/html/20072008/897.html
# Processing file ../../data/raw/html/20072008/194.html
# Processing file ../../data/raw/html/20072008/301.html
# Processing file ../../data/raw/html/20072008/751.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/244.html
# Processing file ../../data/raw/html/20072008/614.html
# Processing file ../../data/raw/html/20072008/35.html
# Processing file ../../data/raw/html/20072008/1158.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/497.html
# Processing file ../../data/raw/html/20072008/182.html
# Processing file ../../data/raw/html/20072008/478.html
# Processing file ../../data/raw/html/20072008/881.html
# Processing file ../../data/raw/html/20072008/706.html
# Processing file ../../data/raw/html/20072008/356.html
# Processing file ../../data/raw/html/20072008/643.html
# Processing file ../../data/raw/html/20072008/1226.html
# Processing file ../../data/raw/html/20072008/213.html
# Processing file ../../data/raw/html/20072008/839.html
# Processing file ../../data/raw/html/20072008/62.html
# Processing file ../../data/raw/html/20072008/993.html
# Processing file ../../data/raw/html/20072008/9.html
# Processing file ../../data/raw/html/20072008/585.html
# Processing file ../../data/raw/html/20072008/638.html
# Processing file ../../data/raw/html/20072008/792.html
# Processing file ../../data/raw/html/20072008/268.html
# Processing file ../../data/raw/html/20072008/287.html
# Processing file ../../data/raw/html/20072008/907.html
# Processing file ../../data/raw/html/20072008/1031.html
# Processing file ../../data/raw/html/20072008/454.html
# Processing file ../../data/raw/html/20072008/1174.html
# Processing file ../../data/raw/html/20072008/141.html
# Processing file ../../data/raw/html/20072008/511.html
# Processing file ../../data/raw/html/20072008/842.html
# Processing file ../../data/raw/html/20072008/19.html
# Processing file ../../data/raw/html/20072008/395.html
# Processing file ../../data/raw/html/20072008/680.html
# Processing file ../../data/raw/html/20072008/403.html
# Processing file ../../data/raw/html/20072008/1066.html
# Processing file ../../data/raw/html/20072008/950.html
# Processing file ../../data/raw/html/20072008/815.html
# Processing file ../../data/raw/html/20072008/1089.html
# Processing file ../../data/raw/html/20072008/546.html
# Processing file ../../data/raw/html/20072008/116.html
# Processing file ../../data/raw/html/20072008/1123.html
# Processing file ../../data/raw/html/20072008/383.html
# Processing file ../../data/raw/html/20072008/679.html
# Processing file ../../data/raw/html/20072008/229.html
# Processing file ../../data/raw/html/20072008/696.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/946.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1070.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/415.html
# Processing file ../../data/raw/html/20072008/1135.html
# Processing file ../../data/raw/html/20072008/100.html
# Processing file ../../data/raw/html/20072008/550.html
# Processing file ../../data/raw/html/20072008/803.html
# Processing file ../../data/raw/html/20072008/58.html
# Processing file ../../data/raw/html/20072008/784.html
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/291.html
# Processing file ../../data/raw/html/20072008/442.html
# Unable to parse game for file ../../data/raw/html/20072008/442.html
# list index out of range
# Processing file ../../data/raw/html/20072008/1027.html
# Processing file ../../data/raw/html/20072008/911.html
# Processing file ../../data/raw/html/20072008/854.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:16:02
# Goalie was back in the net
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/507.html
# Processing file ../../data/raw/html/20072008/157.html
# Processing file ../../data/raw/html/20072008/1162.html
# Processing file ../../data/raw/html/20072008/1115.html
# Processing file ../../data/raw/html/20072008/120.html
# Processing file ../../data/raw/html/20072008/570.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/823.html
# Processing file ../../data/raw/html/20072008/78.html
# Processing file ../../data/raw/html/20072008/989.html
# Processing file ../../data/raw/html/20072008/966.html
# Processing file ../../data/raw/html/20072008/97.html
# Processing file ../../data/raw/html/20072008/1050.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:14:20
# Goalie was back in the net
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/435.html
# Processing file ../../data/raw/html/20072008/659.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:03:26
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:17:04
# Goalie was back in the net
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/209.html
# Processing file ../../data/raw/html/20072008/874.html
# Processing file ../../data/raw/html/20072008/527.html
# Processing file ../../data/raw/html/20072008/177.html
# Processing file ../../data/raw/html/20072008/1142.html
# Processing file ../../data/raw/html/20072008/198.html
# Processing file ../../data/raw/html/20072008/462.html
# Processing file ../../data/raw/html/20072008/1007.html
# Processing file ../../data/raw/html/20072008/931.html
# Processing file ../../data/raw/html/20072008/1154.html
# Processing file ../../data/raw/html/20072008/161.html
# Processing file ../../data/raw/html/20072008/531.html
# Processing file ../../data/raw/html/20072008/862.html
# Processing file ../../data/raw/html/20072008/39.html
# Processing file ../../data/raw/html/20072008/927.html
# Processing file ../../data/raw/html/20072008/1011.html
# Processing file ../../data/raw/html/20072008/474.html
# Processing file ../../data/raw/html/20072008/618.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/248.html
# Processing file ../../data/raw/html/20072008/835.html
# Processing file ../../data/raw/html/20072008/566.html
# Processing file ../../data/raw/html/20072008/136.html
# Processing file ../../data/raw/html/20072008/1103.html
# Processing file ../../data/raw/html/20072008/423.html
# Processing file ../../data/raw/html/20072008/589.html
# Processing file ../../data/raw/html/20072008/1046.html
# Processing file ../../data/raw/html/20072008/81.html
# Processing file ../../data/raw/html/20072008/5.html
# Processing file ../../data/raw/html/20072008/970.html
# Processing file ../../data/raw/html/20072008/458.html
# Processing file ../../data/raw/html/20072008/1197.html
# Processing file ../../data/raw/html/20072008/15.html
# Processing file ../../data/raw/html/20072008/1178.html
# Processing file ../../data/raw/html/20072008/264.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:16:48
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/634.html
# Processing file ../../data/raw/html/20072008/321.html
# Processing file ../../data/raw/html/20072008/771.html
# Processing file ../../data/raw/html/20072008/1085.html
# Processing file ../../data/raw/html/20072008/819.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:06:20
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:31
# Found empty net goal:
# {'team_name': 'MTL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:43'), 'goal_against_time': Timedelta('0 days 00:19:31')}
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/42.html
# Processing file ../../data/raw/html/20072008/399.html
# Processing file ../../data/raw/html/20072008/663.html
# Processing file ../../data/raw/html/20072008/1206.html
# Processing file ../../data/raw/html/20072008/233.html
# Processing file ../../data/raw/html/20072008/726.html
# Processing file ../../data/raw/html/20072008/376.html
# Processing file ../../data/raw/html/20072008/419.html
# Processing file ../../data/raw/html/20072008/54.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:17:33
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:01:10
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:06:35
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:01
# Found empty net goal:
# {'team_name': 'OTT', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:39'), 'goal_against_time': Timedelta('0 days 00:19:01')}
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1093.html
# Processing file ../../data/raw/html/20072008/1139.html
# Processing file ../../data/raw/html/20072008/225.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:12:10
# Goalie was back in the net
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1210.html
# Processing file ../../data/raw/html/20072008/675.html
# Processing file ../../data/raw/html/20072008/360.html
# Processing file ../../data/raw/html/20072008/730.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:12:09
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:05:45
# Goalie was back in the net
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1181.html
# Processing file ../../data/raw/html/20072008/858.html
# Processing file ../../data/raw/html/20072008/622.html
# Processing file ../../data/raw/html/20072008/788.html
# Processing file ../../data/raw/html/20072008/272.html
# Processing file ../../data/raw/html/20072008/767.html
# Processing file ../../data/raw/html/20072008/337.html
# Processing file ../../data/raw/html/20072008/623.html
# Processing file ../../data/raw/html/20072008/789.html
# Processing file ../../data/raw/html/20072008/273.html
# Processing file ../../data/raw/html/20072008/766.html
# Processing file ../../data/raw/html/20072008/336.html
# Processing file ../../data/raw/html/20072008/1180.html
# Processing file ../../data/raw/html/20072008/859.html
# Processing file ../../data/raw/html/20072008/224.html
# Processing file ../../data/raw/html/20072008/1211.html
# Processing file ../../data/raw/html/20072008/674.html
# Processing file ../../data/raw/html/20072008/361.html
# Processing file ../../data/raw/html/20072008/731.html
# Processing file ../../data/raw/html/20072008/418.html
# Processing file ../../data/raw/html/20072008/55.html
# Processing file ../../data/raw/html/20072008/1092.html
# Processing file ../../data/raw/html/20072008/1138.html
# Processing file ../../data/raw/html/20072008/398.html
# Processing file ../../data/raw/html/20072008/662.html
# Processing file ../../data/raw/html/20072008/1207.html
# Processing file ../../data/raw/html/20072008/232.html
# Processing file ../../data/raw/html/20072008/727.html
# Processing file ../../data/raw/html/20072008/377.html
# Processing file ../../data/raw/html/20072008/1084.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/818.html
# Processing file ../../data/raw/html/20072008/43.html
# Processing file ../../data/raw/html/20072008/265.html
# Processing file ../../data/raw/html/20072008/635.html
# Processing file ../../data/raw/html/20072008/320.html
# Processing file ../../data/raw/html/20072008/770.html
# Processing file ../../data/raw/html/20072008/1196.html
# Processing file ../../data/raw/html/20072008/459.html
# Processing file ../../data/raw/html/20072008/14.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1179.html
# Processing file ../../data/raw/html/20072008/834.html
# Processing file ../../data/raw/html/20072008/567.html
# Processing file ../../data/raw/html/20072008/137.html
# Processing file ../../data/raw/html/20072008/1102.html
# Processing file ../../data/raw/html/20072008/422.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1047.html
# Processing file ../../data/raw/html/20072008/588.html
# Processing file ../../data/raw/html/20072008/971.html
# Processing file ../../data/raw/html/20072008/4.html
# Processing file ../../data/raw/html/20072008/80.html
# Processing file ../../data/raw/html/20072008/619.html
# Processing file ../../data/raw/html/20072008/249.html
# Processing file ../../data/raw/html/20072008/1155.html
# Processing file ../../data/raw/html/20072008/160.html
# Processing file ../../data/raw/html/20072008/530.html
# Processing file ../../data/raw/html/20072008/863.html
# Processing file ../../data/raw/html/20072008/38.html
# Processing file ../../data/raw/html/20072008/926.html
# Processing file ../../data/raw/html/20072008/1010.html
# Processing file ../../data/raw/html/20072008/475.html
# Processing file ../../data/raw/html/20072008/875.html
# Processing file ../../data/raw/html/20072008/526.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/176.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:01:26
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:09:24
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:38
# Found empty net goal:
# {'team_name': 'ATL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:53'), 'goal_against_time': Timedelta('0 days 00:19:38')}
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1143.html
# Processing file ../../data/raw/html/20072008/199.html
# Processing file ../../data/raw/html/20072008/463.html
# Processing file ../../data/raw/html/20072008/1006.html
# Processing file ../../data/raw/html/20072008/930.html
# Processing file ../../data/raw/html/20072008/658.html
# Processing file ../../data/raw/html/20072008/208.html
# Processing file ../../data/raw/html/20072008/1114.html
# Processing file ../../data/raw/html/20072008/121.html
# Processing file ../../data/raw/html/20072008/571.html
# Processing file ../../data/raw/html/20072008/822.html
# Processing file ../../data/raw/html/20072008/988.html
# Processing file ../../data/raw/html/20072008/79.html
# Processing file ../../data/raw/html/20072008/96.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/967.html
# Processing file ../../data/raw/html/20072008/1051.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:24
# Found empty net goal:
# {'team_name': 'BOS', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:49'), 'goal_against_time': Timedelta('0 days 00:19:24')}
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/434.html
# Processing file ../../data/raw/html/20072008/443.html
# Processing file ../../data/raw/html/20072008/1026.html
# Processing file ../../data/raw/html/20072008/910.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/855.html
# Processing file ../../data/raw/html/20072008/506.html
# Processing file ../../data/raw/html/20072008/156.html
# Processing file ../../data/raw/html/20072008/1163.html
# Processing file ../../data/raw/html/20072008/785.html
# Processing file ../../data/raw/html/20072008/290.html
# Processing file ../../data/raw/html/20072008/947.html
# Processing file ../../data/raw/html/20072008/1071.html
# Processing file ../../data/raw/html/20072008/414.html
# Processing file ../../data/raw/html/20072008/1134.html
# Processing file ../../data/raw/html/20072008/101.html
# Processing file ../../data/raw/html/20072008/551.html
# Processing file ../../data/raw/html/20072008/802.html
# Processing file ../../data/raw/html/20072008/59.html
# Processing file ../../data/raw/html/20072008/382.html
# Processing file ../../data/raw/html/20072008/678.html
# Processing file ../../data/raw/html/20072008/228.html
# Processing file ../../data/raw/html/20072008/697.html
# Processing file ../../data/raw/html/20072008/402.html
# Processing file ../../data/raw/html/20072008/1067.html
# Processing file ../../data/raw/html/20072008/951.html
# Processing file ../../data/raw/html/20072008/814.html
# Processing file ../../data/raw/html/20072008/547.html
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/1088.html
# Processing file ../../data/raw/html/20072008/117.html
# Processing file ../../data/raw/html/20072008/1122.html
# Processing file ../../data/raw/html/20072008/394.html
# Processing file ../../data/raw/html/20072008/681.html
# Processing file ../../data/raw/html/20072008/906.html
# Processing file ../../data/raw/html/20072008/1030.html
# Processing file ../../data/raw/html/20072008/455.html
# Processing file ../../data/raw/html/20072008/1175.html
# Processing file ../../data/raw/html/20072008/140.html
# Processing file ../../data/raw/html/20072008/510.html
# Processing file ../../data/raw/html/20072008/843.html
# Processing file ../../data/raw/html/20072008/18.html
# Processing file ../../data/raw/html/20072008/639.html
# Processing file ../../data/raw/html/20072008/793.html
# Processing file ../../data/raw/html/20072008/269.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/286.html
# Processing file ../../data/raw/html/20072008/838.html
# Processing file ../../data/raw/html/20072008/992.html
# Processing file ../../data/raw/html/20072008/63.html
# Processing file ../../data/raw/html/20072008/8.html
# Unable to parse game for file ../../data/raw/html/20072008/8.html
# list index out of range
# Processing file ../../data/raw/html/20072008/584.html
# Processing file ../../data/raw/html/20072008/707.html
# Processing file ../../data/raw/html/20072008/357.html
# Processing file ../../data/raw/html/20072008/642.html
# Processing file ../../data/raw/html/20072008/1227.html
# Processing file ../../data/raw/html/20072008/212.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:14:23
# Goalie was back in the net
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/34.html
# Processing file ../../data/raw/html/20072008/496.html
# Processing file ../../data/raw/html/20072008/1159.html
# Processing file ../../data/raw/html/20072008/183.html
# Processing file ../../data/raw/html/20072008/479.html
# Processing file ../../data/raw/html/20072008/880.html
# Processing file ../../data/raw/html/20072008/300.html
# Processing file ../../data/raw/html/20072008/750.html
# Processing file ../../data/raw/html/20072008/245.html
# Processing file ../../data/raw/html/20072008/615.html
# Processing file ../../data/raw/html/20072008/480.html
# Processing file ../../data/raw/html/20072008/879.html
# Processing file ../../data/raw/html/20072008/22.html
# Processing file ../../data/raw/html/20072008/896.html
# Processing file ../../data/raw/html/20072008/195.html
# Processing file ../../data/raw/html/20072008/746.html
# Processing file ../../data/raw/html/20072008/316.html
# Processing file ../../data/raw/html/20072008/603.html
# Processing file ../../data/raw/html/20072008/253.html
# Processing file ../../data/raw/html/20072008/75.html
# Processing file ../../data/raw/html/20072008/984.html
# Processing file ../../data/raw/html/20072008/1118.html
# Processing file ../../data/raw/html/20072008/438.html
# Processing file ../../data/raw/html/20072008/592.html
# Processing file ../../data/raw/html/20072008/341.html
# Processing file ../../data/raw/html/20072008/711.html
# Processing file ../../data/raw/html/20072008/204.html
# Processing file ../../data/raw/html/20072008/654.html
# Processing file ../../data/raw/html/20072008/825.html
# Processing file ../../data/raw/html/20072008/126.html
# Processing file ../../data/raw/html/20072008/1113.html
# Processing file ../../data/raw/html/20072008/576.html
# Processing file ../../data/raw/html/20072008/1056.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/599.html
# Processing file ../../data/raw/html/20072008/433.html
# Processing file ../../data/raw/html/20072008/960.html
# Processing file ../../data/raw/html/20072008/91.html
# Processing file ../../data/raw/html/20072008/521.html
# Processing file ../../data/raw/html/20072008/1144.html
# Processing file ../../data/raw/html/20072008/171.html
# Processing file ../../data/raw/html/20072008/29.html
# Processing file ../../data/raw/html/20072008/872.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20072008/937.html
# Processing file ../../data/raw/html/20072008/464.html
# Processing file ../../data/raw/html/20072008/1001.html
# Processing file ../../data/raw/html/20072008/258.html
# Processing file ../../data/raw/html/20072008/608.html
# Processing file ../../data/raw/html/20072008/864.html
# Processing file ../../data/raw/html/20072008/167.html
# Processing file ../../data/raw/html/20072008/1152.html
# Processing file ../../data/raw/html/20072008/537.html
# Processing file ../../data/raw/html/20072008/1017.html
# Processing file ../../data/raw/html/20072008/188.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:01:18
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:02:33
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# ...
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:00:00
# Goalie was back in the net
# Processing file ../../data/raw/html/20082009/851.html
# Processing file ../../data/raw/html/20082009/502.html
# Processing file ../../data/raw/html/20082009/1167.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:02:26
# Goalie was back in the net
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:02:58
# Found empty net goal:
# {'team_name': 'PHI', 'pull_period': 2, 'pull_time': Timedelta('0 days 00:02:56'), 'goal_for_time': Timedelta('0 days 00:02:58')}
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/152.html
# Processing file ../../data/raw/html/20082009/447.html
# Processing file ../../data/raw/html/20082009/1188.html
# Processing file ../../data/raw/html/20082009/1022.html
# Processing file ../../data/raw/html/20082009/914.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:11:26
# Goalie was back in the net
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/963.html
# Processing file ../../data/raw/html/20082009/92.html
# Processing file ../../data/raw/html/20082009/1055.html
# Processing file ../../data/raw/html/20082009/430.html
# Processing file ../../data/raw/html/20082009/125.html
# Processing file ../../data/raw/html/20082009/1110.html
# Processing file ../../data/raw/html/20082009/575.html
# Processing file ../../data/raw/html/20082009/826.html
# Processing file ../../data/raw/html/20082009/719.html
# Processing file ../../data/raw/html/20082009/349.html
# Processing file ../../data/raw/html/20082009/467.html
# Processing file ../../data/raw/html/20082009/1002.html
# Processing file ../../data/raw/html/20082009/934.html
# Processing file ../../data/raw/html/20082009/871.html
# Processing file ../../data/raw/html/20082009/522.html
# Processing file ../../data/raw/html/20082009/1147.html
# Processing file ../../data/raw/html/20082009/488.html
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/172.html
# Processing file ../../data/raw/html/20082009/922.html
# Processing file ../../data/raw/html/20082009/888.html
# Processing file ../../data/raw/html/20082009/1014.html
# Processing file ../../data/raw/html/20082009/471.html
# Processing file ../../data/raw/html/20082009/164.html
# Processing file ../../data/raw/html/20082009/1151.html
# Processing file ../../data/raw/html/20082009/534.html
# Processing file ../../data/raw/html/20082009/867.html
# Processing file ../../data/raw/html/20082009/758.html
# Processing file ../../data/raw/html/20082009/308.html
# Processing file ../../data/raw/html/20082009/426.html
# Processing file ../../data/raw/html/20082009/1043.html
# Processing file ../../data/raw/html/20082009/84.html
# Processing file ../../data/raw/html/20082009/975.html
# Unable to parse game for file ../../data/raw/html/20082009/975.html
# list index out of range
# Processing file ../../data/raw/html/20082009/830.html
# Processing file ../../data/raw/html/20082009/563.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/1106.html
# Processing file ../../data/raw/html/20082009/133.html
# Processing file ../../data/raw/html/20082009/10.html
# Processing file ../../data/raw/html/20082009/518.html
# Processing file ../../data/raw/html/20082009/148.html
# Processing file ../../data/raw/html/20082009/1192.html
# Processing file ../../data/raw/html/20082009/1038.html
# Processing file ../../data/raw/html/20082009/324.html
# Processing file ../../data/raw/html/20082009/774.html
# Processing file ../../data/raw/html/20082009/261.html
# Processing file ../../data/raw/html/20082009/631.html
# Unable to parse game for file ../../data/raw/html/20082009/631.html
# list index out of range
# Processing file ../../data/raw/html/20082009/1080.html
# Processing file ../../data/raw/html/20082009/47.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/959.html
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:04:03
# Found empty net goal:
# {'team_name': 'OTT', 'pull_period': 2, 'pull_time': Timedelta('0 days 00:03:57.500000'), 'goal_for_time': Timedelta('0 days 00:04:03')}
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/723.html
# Processing file ../../data/raw/html/20082009/689.html
# Processing file ../../data/raw/html/20082009/373.html
# Processing file ../../data/raw/html/20082009/666.html
# Processing file ../../data/raw/html/20082009/236.html
# Processing file ../../data/raw/html/20082009/1203.html
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:00
# Found empty net goal:
# {'team_name': 'OTT', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:07.500000'), 'goal_for_time': Timedelta('0 days 00:19:00')}
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:00:00
# Goalie was back in the net
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../../data/raw/html/20082009/51.html
# Processing file ../../data/raw/html/20082009/1096.html
# Processing file ../../data/raw/html/20082009/559.html
# Processing file ../../data/raw/html/20082009/109.html
# Processing file ../../data/raw/html/20082009/1079.html
# Processing file ../../data/raw/html/20082009/365.html
# Processing file ../../data/raw/html/20082009/735.html
# Processing file ../../data/raw/html/20082009/1215.html
# Processing file ../../data/raw/html/20082009/220.html
# Processing file ../../data/raw/html/20082009/670.html
# Processing file ../../data/raw/html/20082009/918.html
# Processing file ../../data/raw/html/20082009/1184.html
# Processing file ../../data/raw/html/20082009/298.html
# Processing file ../../data/raw/html/20082009/762.html
# Processing file ../../data/raw/html/20082009/332.html
# Processing file ../../data/raw/html/20082009/627.html
# Processing file ../../data/raw/html/20082009/277.html
# Processing file ../../data/raw/html/20082009/505.html
# Processing file ../../data/raw/html/20082009/155.html
# Processing file ../../data/raw/html/20082009/1160.html
