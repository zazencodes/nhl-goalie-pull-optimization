# %%
from IPython.display import HTML
HTML('<style>div.text_cell_render{font-size:130%;}</style>')
# %load_ext version_information
# %version_information pandas
# Out:
# Software versions
# Python 3.7.1 64bit [Clang 4.0.1 (tags/RELEASE_401/final)]
# IPython 7.2.0
# OS Darwin 18.2.0 x86_64 i386 64bit
# pandas 0.23.4
# Tue Apr 23 17:59:12 2019 PDT

# %% [markdown]
# # Goalie Pull Bayes Optimize
#
#  - Parse the goalie pull stats we need
#
# ### This script is for the newest format: *2017/2018* and later (something changed this year)

# %% [markdown]
# Sample games:
#
# http://www.nhl.com/scores/htmlreports/20032004/PL020001.HTM
# file:///Users/alex/Documents/nhl-goalie-pull-optimization/data/raw/html/20072008/980.html
# file:///Users/alex/Documents/nhl-goalie-pull-optimization/data/raw/html/20072008/980.html

# %% [markdown]
# ## Parse HTML Stats Table

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import re
import datetime
import time
from collections import OrderedDict
import glob
from tqdm import tqdm_notebook
from colorama import Fore, Style

# %% [markdown]
# ### Helper functions

# %%
def is_int(x):
    try:
        int(x)
        return True
    except:
        return False

def parse_time(s):
    _s = s.copy()
    _s = _s.apply(lambda x:
        datetime.datetime.strptime(x[:5], '%M:%S')
    )
    _s = _s.apply(lambda x:
        datetime.timedelta(
        hours=x.hour,
        minutes=x.minute,
        seconds=x.second,
        microseconds=x.microsecond
    ))
    return _s

def parse_date(s):
    _s = s.copy()
    
    # invalid parsing will be set as NaT
    _s = pd.to_datetime(_s, errors='coerce')

    '''
     _s = _s.apply(lambda x: (re.search(',(.*)', x.text.splitlines()[2])
                             .group(1)
                             .strip()))
     _s = _s.apply(lambda x: datetime.datetime\
                             .strptime(x.strip(), '%B %d, %Y'))
    '''
    
    return _s

def goalie_pull_timedelta(s1, s2):
    out = []
    for d1, d2 in zip(s1.values, s2.values):
        try:
            o = d1 - d2
        except:
            o = float('nan')
        out.append(o)
    return out

# %% [markdown]
# ### Main Functions

# %%
def get_game_df(
    soup,
    local_html=True,
) -> pd.DataFrame:
    '''
    Returns the parsed HTML stats table for some game and returns
    a DataFrame.
    
    local_html : bool
        Set True if using local HTML file. Otherwise set False
        for requested HTML from nhl.com
    '''
    
    # Parse main table
    table = soup.find_all('pre')[0]
    raw_table = table.text

    if local_html:
        lines = [line for line in
             raw_table.split('\r\n')[0].split('\n')
             if line.strip()]
    else:
        lines = [line for line in
             raw_table.split('\r\n')
             if line.strip()]

    # Get row split indices
    j = 0
    switch = False
    idx = []
    for i, char in enumerate(lines[1]):
        if char == ' ':
            switch = True
        elif (char == '-') and switch:
            switch = False
            idx.append([j, i])
            j = i
    idx.append([idx[-1][1], None])
    idx = [slice(*x) for x in idx]
    
    # Split data and load to df
    data = []
    for i, line in enumerate(lines):
        if i == 1:
            continue
        d = np.empty((7,), dtype=object) 
        for j, _slice in enumerate(idx):
            d[j] = line[_slice].strip()
        data.append(d)
    
    df = pd.DataFrame(data[1:], columns=[col.strip().lower()
                                         for col in data[0]])
    
    # Check for missing columns
    for col in ['#', 'per', 'time', 'event', 'team', 'type', 'description']:
        if col not in df.columns:
            print(f'Missing column: {col}')
    
    # Basic clean up
    players_on_ice = {}
    prev_num = None
    for i, row in df.iterrows():
        if not is_int(row['#']):
            if ((prev_num not in players_on_ice.keys()
                and (row is not None))
                ):
                players_on_ice[prev_num] = ''
            players_on_ice[prev_num] += ''.join(row.values)
            continue
        prev_num = row['#']
    
    good_rows = df['#'].apply(is_int)
    df = df.loc[good_rows]
    df['#'] = df['#'].astype(int)
    df['per'] = df['per'].astype(int)
    df['time'] = parse_time(df['time'])
    
    return df, players_on_ice

# %% [markdown]
# ### Load data sample

# %%
with open('../../data/raw/html/20172018/980.html', 'r') as f:
    soup = BeautifulSoup(f.read(), 'lxml')

# %%
df = get_game_df(soup)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-09d72922ac9a> in <module>
# ----> 1 df = get_game_df(soup)
#
# <ipython-input-5-e785d8008ca5> in get_game_df(soup, local_html)
#      13
#      14     # Parse main table
# ---> 15     table = soup.find_all('pre')[0]
#      16     raw_table = table.text
#      17
#
# IndexError: list index out of range

# %% [markdown]
# Old functions are not going to work for us.. will need to re-create everything here
#
# ### get_game_df

# %%
len(soup.find_all('table'))
# Out:
# 4106

# %%
table = soup.find_all('table')[0]
raw_table = table.text

# %%
table.find_all('tr')[400]
# Out:
# <tr>
# <td align="center">
# <font style="cursor:hand;" title="Goalie - CARTER HUTTON">40</font>
# </td>
# </tr>

# %%
' '.join(table.attrs['class'])
# Out:
# 'tablewidth'

# %%
team_names = []
for row_data in soup.find_all('td', {'class': 'heading + bborder'}):
    if 'on ice' in row_data.text.lower():
        team_names.append(row_data.text.split()[0])
    if len(team_names) == 2:
        break

if len(team_names) != 2:
    team_names = ['', '']

# %%
team_names
# Out:
# ['DET', 'STL']

# %%
def test():

    data = []

    for row in soup.find_all('tr', {'class': 'evenColor'}):
        d = []
        for i, row_data in enumerate(row.find_all('td')):
            if 'class' in row_data.attrs:
                classes = ' '.join(row_data.attrs['class'])
                if 'bborder' not in classes:
                    continue
            else:
                continue

            if i == 3:
#                 print(row)
                return row_data

            row_data_text = row_data.text.strip()
            if i >= 6:
                row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data_text))

            d.append(row_data_text)

        if len(d) >= 8:
            data.append(d[:8])
            
el = test()

# %%
str(el.contents[0])
# Out:
# '0:00'

# %%
data = []

for row in soup.find_all('tr', {'class': 'evenColor'}):
    d = []
    for i, row_data in enumerate(row.find_all('td')):
        if 'class' in row_data.attrs:
            classes = ' '.join(row_data.attrs['class'])
            if 'bborder' not in classes:
                continue
        else:
            continue
            
        row_data_text = row_data.text.strip()
        if i >= 6:
            row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data_text))
            
        d.append(row_data_text)

    if len(d) >= 8:
        data.append(d[:8])

# %%
data[:3]
# Out:
# [['1', '1', '', '0:0020:00', 'PGSTR', '', '', ''],
#  ['2', '1', '', '0:0020:00', 'PGEND', '', '', ''],
#  ['3', '1', '', '0:0020:00', 'ANTHEM', '', '', '']]

# %%
def parse_time(s):
    _s = s.copy()
    _s = _s.apply(        
        lambda x:
        datetime.datetime.strptime(x.split(' ')[0], '%M:%S')
    )
    _s = _s.apply(lambda x:
        datetime.timedelta(
        hours=x.hour,
        minutes=x.minute,
        seconds=x.second,
        microseconds=x.microsecond
    ))
    return _s

def parse_team(s):
    _s = s.copy()
    _s = _s.str.split().apply(lambda x: x[0])
    return _s

# %%
def get_game_df(
    soup,
    local_html=True,
) -> pd.DataFrame:
    '''
    Returns the parsed HTML stats table for some game and returns
    a DataFrame.
    
    local_html : bool
        Set True if using local HTML file. Otherwise set False
        for requested HTML from nhl.com
    '''

    if not local_html:
        raise NotImplementedError('Only local HTML supported')

    # Parse the main table
    data = []
    for row in soup.find_all('tr', {'class': 'evenColor'}):
        d = []
        for i, row_data in enumerate(row.find_all('td')):
            if 'class' in row_data.attrs:
                classes = ' '.join(row_data.attrs['class'])
                if 'bborder' not in classes:
                    continue
            else:
                continue

            if i == 3:
                # Parse the time
                row_data_text = ' '.join([str(s) for s in row_data.contents])

            elif i >= 6:
                # Parse the players on ice
                row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data.text.strip()))

            else:
                # Standard parse
                row_data_text = row_data.text.strip()
                
            d.append(row_data_text)

        if len(d) >= 8:
            data.append(d[:8])
    
    cols = ['#', 'per', 'type', 'time', 'event', 'description', 'visitor_on_ice', 'home_on_ice']
    df = pd.DataFrame(data, columns=cols)
    
    good_rows = df['#'].apply(is_int)
    df = df.loc[good_rows]
    df['#'] = df['#'].astype(int)
    df['per'] = df['per'].astype(int)
    df['time'] = parse_time(df['time'])
    df['team'] = parse_team(df['description'])
    
    # Get the team info
    team_names = []
    for row_data in soup.find_all('td', {'class': 'heading + bborder'}):
        if 'on ice' in row_data.text.lower():
            team_names.append(row_data.text.split()[0])
        if len(team_names) == 2:
            break
    if len(team_names) != 2:
        team_names = ['', '']
    team_info = {'visitor': team_names[0], 'home': team_names[1]}
    
    return df, team_info

# %%
df, team_info = get_game_df(soup)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-ac5af0f0f512> in <module>
# ----> 1 df, team_info = get_game_df(soup)
#
# <ipython-input-19-e95d7fa47126> in get_game_df(soup, local_html)
#      52     df['per'] = df['per'].astype(int)
#      53     df['time'] = parse_time(df['time'])
# ---> 54     df['team'] = parse_team(df['description'])
#      55
#      56     # Get the team info
#
# <ipython-input-18-2fcb899f75fe> in parse_team(s)
#      16 def parse_team(s):
#      17     _s = s.copy()
# ---> 18     _s = _s.str.split().apply(lambda x: x[0])
#      19     return _s
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-18-2fcb899f75fe> in <lambda>(x)
#      16 def parse_team(s):
#      17     _s = s.copy()
# ---> 18     _s = _s.str.split().apply(lambda x: x[0])
#      19     return _s
#
# IndexError: list index out of range

# %%
soup.text[:1000]
# Out:
# '\n\n\nPlay By Play\n\n\n\t\t\t\t@media screen\n\t\t\t\t{\n\t\t\t\t     .print-class { display: block;}\n\t\t\t\t}\n\t\t\t\t@media print\n\t\t\t\t{\n\t\t\t\t     .print-class { display: none;}\n\t\t\t\t}\n\n\t\t\t\tbody {border:solid; border-width: 0;}\n\t\t\t\tp, td {font-family: arial,verdana; font-size: 9px;}\n\t\t\t\t.tablewidth{width:650px;}\n\t\t\t\t.heading {font-weight:bold;}\n\t\t\t\t.goal{font-weight: bold;font-size:11px;}\n\t\t\t\t.penalty{font-style: italic;font-size:11px;}\n\t\t\t\t.border {border:1px solid black;border-collapse: collapse;}\n\t\t\t\t.noborder {border:0px solid black;border-collapse: collapse;}\n\t\t\t\t.tborder{border-top:1px solid black;}\n\t\t\t\t.bborder{border-bottom:1px solid black;}\n\t\t\t\t.lborder{border-left:1px solid black;}\n\t\t\t\t.rborder{border-right:1px solid black;}\n\t\t\t\t.oddColor{background-color: #E7E7E7;}\n\t\t\t\t.evenColor{background-color: #FFFFFF;}\n\t\t\t\t.bold{font-weight:bold;}\n\t\t\t\t.italicize{font-style: italic;}\n\t\t\t\t.spacer{font-size:1px;height:5px;}\n\t\t\t\t.pageBreakAfter{page-break-after: always;}\n\t\t\t\t.pageBreakBefore{page-break-before: always'

# %%
# Parse the main table
data = []
for row in soup.find_all('tr', {'class': 'evenColor'}):
    d = []
    for i, row_data in enumerate(row.find_all('td')):
        if 'class' in row_data.attrs:
            classes = ' '.join(row_data.attrs['class'])
            if 'bborder' not in classes:
                continue
        else:
            continue
            
        if i == 3:
            # Parse the time
            row_data_text = ' '.join([str(s) for s in row_data.contents])

        elif i >= 6:
            # Parse the players on ice
            row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data.text.strip()))

        else:
            # Standard parse
            row_data_text = row_data.text.strip()

        d.append(row_data_text)

    print(d)
        
    if len(d) >= 8:
        data.append(d[:8])
# Out:
# ['1', '1', '', '0:00 <br/> 20:00', 'PGSTR', '', '', '']
# ['2', '1', '', '0:00 <br/> 20:00', 'PGEND', '', '', '']
# ['3', '1', '', '0:00 <br/> 20:00', 'ANTHEM', '', '', '']
# ['4', '1', '', '0:00 <br/> 20:00', 'PSTR', 'Period Start- Local time: 7:10 CST', 'C C L D D G', 'C R R D D G']
# ['5', '1', 'EV', '0:00 <br/> 20:00', 'FAC', 'STL won Neu. Zone - DET #51 NIELSEN vs STL #28 BRODZIAK', 'C C L D D G', 'C R R D D G']
# ['6', '1', '', '0:14 <br/> 19:46', 'STOP', 'PUCK IN BENCHES', 'C C L D D G', 'C R R D D G']
# ['7', '1', 'EV', '0:14 <br/> 19:46', 'FAC', 'STL won Neu. Zone - DET #40 ZETTERBERG vs STL #49 BARBASHEV', 'C C R D D G', 'C R L D D G']
# ['8', '1', '', '0:18 <br/> 19:42', 'STOP', 'PUCK IN BENCHES', 'C C R D D G', 'C R L D D G']
# ['9', '1', 'EV', '0:18 <br/> 19:42', 'FAC', 'DET won Neu. Zone - DET #40 ZETTERBERG vs STL #49 BARBASHEV', 'C C R D D G', 'C R L D D G']
# ['28', '1', 'EV', '3:26 <br/> 16:34', 'SHOT', 'DET ONGOAL - #40 ZETTERBERG, Snap, Off. Zone, 56 ft.', 'C C R D D G', 'C R L D D G']
# ['29', '1', '', '3:27 <br/> 16:33', 'STOP', 'GOALIE STOPPED', 'C C L D D G', 'C R L D D G']
# ['30', '1', 'EV', '3:27 <br/> 16:33', 'FAC', 'STL won Def. Zone - DET #51 NIELSEN vs STL #28 BRODZIAK', 'C C L D D G', 'C R R D D G']
# ['31', '1', 'EV', '3:58 <br/> 16:02', 'PENL', 'STL #9 UPSHALL\xa0Hooking(2 min), Off. Zone Drawn By: DET #43 HELM', 'C C L D D G', 'C R R D D G']
# ['32', '1', 'PP', '3:58 <br/> 16:02', 'FAC', 'DET won Off. Zone - DET #40 ZETTERBERG vs STL #10 SCHENN', 'C C R L D G', 'C C D D G']
# ['33', '1', 'SH', '4:33 <br/> 15:27', 'TAKE', 'STL\xa0TAKEAWAY - #19 BOUWMEESTER, Def. Zone', 'C C R L D G', 'C C D D G']
# ['34', '1', 'SH', '5:10 <br/> 14:50', 'SHOT', 'STL ONGOAL - #90 SOSHNIKOV, Backhand, Off. Zone, 7 ft.', 'C C R L D G', 'R L D D G']
# ['35', '1', '', '5:10 <br/> 14:50', 'STOP', 'GOALIE STOPPED', 'C C R L D G', 'R L D D G']
# ['36', '1', 'PP', '5:10 <br/> 14:50', 'FAC', 'DET won Def. Zone - DET #71 LARKIN vs STL #20 STEEN', 'C C R L D G', 'R L D D G']
# ['37', '1', 'PP', '5:33 <br/> 14:27', 'SHOT', 'DET ONGOAL - #42 FRK, Slap, Off. Zone, 49 ft.', 'C C R L D G', 'R L D D G']
# ['38', '1', 'PP', '5:53 <br/> 14:07', 'SHOT', 'DET ONGOAL - #72 ATHANASIOU, Snap, Off. Zone, 64 ft.', 'C C R L D G', 'C C D D G']
# ['39', '1', '', '5:54 <br/> 14:06', 'STOP', 'GOALIE STOPPED', 'C C R L D G', 'C C D D G']
# ['40', '1', 'SH', '5:54 <br/> 14:06', 'FAC', 'STL won Def. Zone - DET #51 NIELSEN vs STL #28 BRODZIAK', 'C C C D D G', 'C C D D G']
# ['41', '1', 'EV', '6:26 <br/> 13:34', 'TAKE', 'DET\xa0TAKEAWAY - #43 HELM, Neu. Zone', 'C C C D D G', 'C C R D D G']
# ['42', '1', 'EV', '6:37 <br/> 13:23', 'HIT', 'DET #52 ERICSSON HIT STL #91 TARASENKO, Neu. Zone', 'C C C D D G', 'C C R D D G']
# ['43', '1', '', '6:57 <br/> 13:03', 'STOP', 'ICING', 'C C R D D G', 'C C R D D G']
# ['44', '1', 'EV', '6:57 <br/> 13:03', 'FAC', 'STL won Off. Zone - DET #40 ZETTERBERG vs STL #49 BARBASHEV', 'C C R D D G', 'C R L D D G']
# ['45', '1', 'EV', '7:07 <br/> 12:53', 'GIVE', 'STL\xa0GIVEAWAY - #20 STEEN, Off. Zone', 'C C R D D G', 'C R L D D G']
# ['82', '1', 'SH', '15:27 <br/> 4:33', 'BLOCK', 'STL #71 SOBOTKA BLOCKED BY  DET #43 HELM, Wrist, Def. Zone', 'C C D D G', 'C C R D D G']
# ['83', '1', '', '15:28 <br/> 4:32', 'STOP', 'PUCK IN NETTING', 'C C D D G', 'C C R D D G']
# ['84', '1', 'PP', '15:28 <br/> 4:32', 'FAC', 'STL won Off. Zone - DET #51 NIELSEN vs STL #71 SOBOTKA', 'C C D D G', 'C C R D D G']
# ['85', '1', 'EV', '16:12 <br/> 3:48', 'SHOT', 'DET ONGOAL - #42 FRK, Slap, Off. Zone, 41 ft.', 'C R L D D G', 'C R R D D G']
# ['86', '1', 'EV', '16:27 <br/> 3:33', 'MISS', 'DET #71 LARKIN, Wrist, Over Net, Off. Zone, 30 ft.', 'C C L D D G', 'C R R D D G']
# ['87', '1', 'EV', '16:41 <br/> 3:19', 'BLOCK', 'STL #90 SOSHNIKOV BLOCKED BY  DET #61 OUELLET, Snap, Def. Zone', 'C C L D D G', 'C R R D D G']
# ['88', '1', 'EV', '17:33 <br/> 2:27', 'HIT', 'STL #23 JASKIN HIT DET #3 JENSEN, Off. Zone', 'C C R D D G', 'C C R D D G']
# ['89', '1', 'EV', '17:41 <br/> 2:19', 'HIT', 'STL #10 SCHENN HIT DET #3 JENSEN, Off. Zone', 'C C R D D G', 'C C R D D G']
# ['90', '1', 'EV', '17:47 <br/> 2:13', 'SHOT', 'DET ONGOAL - #40 ZETTERBERG, Wrist, Neu. Zone, 85 ft.', 'C C R D D G', 'C R L D D G']
# ['91', '1', 'EV', '18:24 <br/> 1:36', 'SHOT', 'DET ONGOAL - #43 HELM, Wrist, Off. Zone, 43 ft.', 'C C L D D G', 'C R L D D G']
# ['92', '1', 'EV', '18:33 <br/> 1:27', 'BLOCK', 'DET #83 DALEY BLOCKED BY  STL #20 STEEN, Snap, Def. Zone', 'C C L D D G', 'C R L D D G']
# ['93', '1', '', '18:34 <br/> 1:26', 'STOP', 'PUCK IN CROWD', 'C C L D D G', 'C R L D D G']
# ['94', '1', 'EV', '18:34 <br/> 1:26', 'FAC', 'STL won Def. Zone - DET #41 GLENDENING vs STL #71 SOBOTKA', 'C R L D D G', 'C C R D D G']
# ['95', '1', 'EV', '18:58 <br/> 1:02', 'SHOT', 'STL ONGOAL - #28 BRODZIAK, Slap, Off. Zone, 31 ft.', 'C R L D D G', 'C C R D D G']
# ['96', '1', 'EV', '19:04 <br/> 0:56', 'MISS', 'STL #71 SOBOTKA, Slap, Wide of Net, Off. Zone, 32 ft.', 'C R L D D G', 'C C R D D G']
# ['97', '1', 'EV', '19:51 <br/> 0:09', 'GIVE', 'DET\xa0GIVEAWAY - #52 ERICSSON, Def. Zone', 'C C L D D G', 'C C R D D G']
# ['98', '1', 'EV', '19:54 <br/> 0:06', 'MISS', 'STL #91 TARASENKO, Tip-In, Wide of Net, Off. Zone, 22 ft.', 'C C L D D G', 'C C R D D G']
# ['225', '3', 'EV', '7:33 <br/> 12:27', 'SHOT', 'STL ONGOAL - #10 SCHENN, Wrist, Off. Zone, 37 ft.', 'C C R D D G', 'C C R D D G']
# ['226', '3', 'EV', '7:43 <br/> 12:17', 'TAKE', 'STL\xa0TAKEAWAY - #10 SCHENN, Off. Zone', 'C C R D D G', 'C C R D D G']
# ['227', '3', 'EV', '8:12 <br/> 11:48', 'SHOT', 'STL ONGOAL - #10 SCHENN, Wrist, Off. Zone, 35 ft.', 'C C R D D G', 'C C R D D G']
# ['228', '3', 'EV', '8:41 <br/> 11:19', 'MISS', 'DET #8 ABDELKADER, Wrist, Over Net, Off. Zone, 27 ft.', 'C C L D D G', 'C R L D D G']
# ['229', '3', 'EV', '8:55 <br/> 11:05', 'BLOCK', 'STL #91 TARASENKO BLOCKED BY  DET #83 DALEY, Snap, Def. Zone', 'C C L D D G', 'C R L D D G']
# ['230', '3', 'EV', '9:02 <br/> 10:58', 'SHOT', 'DET ONGOAL - #8 ABDELKADER, Snap, Off. Zone, 33 ft.', 'C C L D D G', 'C R L D D G']
# ['231', '3', 'EV', '9:04 <br/> 10:56', 'MISS', 'DET #8 ABDELKADER, Backhand, Over Net, Off. Zone, 12 ft.', 'C C L D D G', 'C R L D D G']
# ['232', '3', '', '9:22 <br/> 10:38', 'STOP', 'OFFSIDE', 'C C L D D G', 'C R R D D G']
# ['233', '3', 'EV', '9:22 <br/> 10:38', 'FAC', 'DET won Def. Zone - DET #41 GLENDENING vs STL #28 BRODZIAK', 'C C L D D G', 'C R R D D G']
# ['234', '3', 'EV', '9:36 <br/> 10:24', 'MISS', 'DET #71 LARKIN, Wrist, Wide of Net, Off. Zone, 22 ft.', 'C C L D D G', 'C R R D D G']
# ['235', '3', 'EV', '9:43 <br/> 10:17', 'SHOT', 'DET ONGOAL - #72 ATHANASIOU, Wrist, Off. Zone, 29 ft.', 'C C L D D G', 'C R R D D G']
# ['236', '3', 'EV', '9:50 <br/> 10:10', 'GIVE', 'STL\xa0GIVEAWAY - #28 BRODZIAK, Neu. Zone', 'C C L D D G', 'C R R D D G']
# ['237', '3', 'EV', '9:57 <br/> 10:03', 'SHOT', 'DET ONGOAL - #71 LARKIN, Backhand, Off. Zone, 42 ft.', 'C C L D D G', 'C R R D D G']
# ['238', '3', 'EV', '10:02 <br/> 9:58', 'SHOT', 'DET ONGOAL - #71 LARKIN, Wrist, Off. Zone, 41 ft.', 'C C L D D G', 'C R R D D G']
# ['239', '3', 'EV', '10:10 <br/> 9:50', 'BLOCK', 'DET #72 ATHANASIOU BLOCKED BY  STL #22 THORBURN, Wrist, Def. Zone', 'C C L D D G', 'C R R D D G']
# ['240', '3', 'EV', '10:25 <br/> 9:35', 'SHOT', 'DET ONGOAL - #39 MANTHA, Wrist, Off. Zone, 6 ft.', 'C C R D D G', 'C C R D D G']
# ['241', '3', '', '10:28 <br/> 9:32', 'STOP', 'PUCK IN CROWD,TV TIMEOUT', 'C C R D D G', 'C C R D D G']
# ['242', '3', 'EV', '10:28 <br/> 9:32', 'FAC', 'STL won Def. Zone - DET #40 ZETTERBERG vs STL #28 BRODZIAK', 'C C R D D G', 'C C C D D G']
# ['260', '3', 'EV', '14:37 <br/> 5:23', 'GOAL', 'STL #27 PIETRANGELO(11), Slap, Off. Zone, 29 ft.Assists: #17 SCHWARTZ(27); #10 SCHENN(33)', 'C C L D D G', 'C C R D D G']
# ['261', '3', 'EV', '14:37 <br/> 5:23', 'FAC', 'DET won Neu. Zone - DET #71 LARKIN vs STL #49 BARBASHEV', 'C C L D D G', 'C R L D D G']
# ['262', '3', 'EV', '14:52 <br/> 5:08', 'BLOCK', 'DET #71 LARKIN BLOCKED BY  STL #55 PARAYKO, Wrist, Def. Zone', 'C C L D D G', 'C R L D D G']
# ['263', '3', 'EV', '14:57 <br/> 5:03', 'BLOCK', 'DET #71 LARKIN BLOCKED BY  STL #55 PARAYKO, Snap, Def. Zone', 'C C L D D G', 'C R L D D G']
# ['264', '3', '', '14:58 <br/> 5:02', 'STOP', 'PUCK IN CROWD,TV TIMEOUT', 'C C L D D G', 'C R L D D G']
# ['265', '3', 'EV', '14:58 <br/> 5:02', 'FAC', 'DET won Off. Zone - DET #40 ZETTERBERG vs STL #71 SOBOTKA', 'C C R D D G', 'C C R D D G']
# ['266', '3', 'EV', '15:10 <br/> 4:50', 'SHOT', 'DET ONGOAL - #55 KRONWALL, Wrist, Off. Zone, 35 ft.', 'C C R D D G', 'C C R D D G']
# ['267', '3', '', '15:11 <br/> 4:49', 'STOP', 'GOALIE STOPPED', 'C C R D D G', 'C C R D D G']
# ['268', '3', 'EV', '15:11 <br/> 4:49', 'FAC', 'DET won Off. Zone - DET #40 ZETTERBERG vs STL #28 BRODZIAK', 'C C R D D G', 'C C R D D G']
# ['269', '3', 'EV', '15:12 <br/> 4:48', 'BLOCK', 'DET #39 MANTHA BLOCKED BY  STL #19 BOUWMEESTER, Slap, Def. Zone', 'C C R D D G', 'C C R D D G']
# ['270', '3', '', '15:13 <br/> 4:47', 'STOP', 'PUCK IN NETTING', 'C C R D D G', 'C C R D D G']
# ['271', '3', 'EV', '15:13 <br/> 4:47', 'FAC', 'DET won Off. Zone - DET #39 MANTHA vs STL #28 BRODZIAK', 'C C R D D G', 'C C R D D G']
# ['272', '3', 'EV', '15:59 <br/> 4:01', 'BLOCK', 'DET #40 ZETTERBERG BLOCKED BY  STL #19 BOUWMEESTER, Slap, Def. Zone', 'C C R D D G', 'C C R D D G']
# ['273', '3', 'EV', '16:10 <br/> 3:50', 'MISS', 'DET #14 NYQUIST, Wrist, Over Net, Off. Zone, 18 ft.', 'C C R D D G', 'C R L D D G']
# ['274', '3', 'EV', '16:20 <br/> 3:40', 'SHOT', 'DET ONGOAL - #40 ZETTERBERG, Backhand, Off. Zone, 13 ft.', 'C C R D D G', 'C R L D D G']
# ['275', '3', '', '16:21 <br/> 3:39', 'STOP', 'GOALIE STOPPED,HOME TIMEOUT', 'C C R D D G', 'C R L D D G']
# ['276', '3', 'EV', '16:21 <br/> 3:39', 'FAC', 'STL won Def. Zone - DET #40 ZETTERBERG vs STL #28 BRODZIAK', 'C C C R L D', 'C C L D D G']
# ['277', '3', 'EV', '16:47 <br/> 3:13', 'BLOCK', 'DET #40 ZETTERBERG BLOCKED BY  STL #27 PIETRANGELO, Wrist, Def. Zone', 'C C C R L D', 'C C L D D G']
# ['278', '3', 'EV', '17:22 <br/> 2:38', 'BLOCK', 'DET #55 KRONWALL BLOCKED BY  STL #27 PIETRANGELO, Wrist, Def. Zone', 'C C C R L D', 'C C R D D G']
# ['279', '3', 'EV', '18:13 <br/> 1:47', 'MISS', 'DET #59 BERTUZZI, Wrist, Hit Crossbar, Off. Zone, 27 ft.', 'C C C R L D', 'C C L D D G']
# ['280', '3', 'EV', '18:15 <br/> 1:45', 'GOAL', 'DET #72 ATHANASIOU(13), Slap, Off. Zone, 30 ft.Assist: #59 BERTUZZI(10)', 'C C C R L D', 'C C L D D G']
# ['281', '3', 'EV', '18:15 <br/> 1:45', 'FAC', 'DET won Neu. Zone - DET #71 LARKIN vs STL #10 SCHENN', 'C C R L D G', 'C C L D D G']
# ['282', '3', 'EV', '18:26 <br/> 1:34', 'MISS', 'STL #20 STEEN, Wrist, Hit Crossbar, Off. Zone, 27 ft.', 'C C R L D G', 'C C L D D G']
# ['283', '3', '', '18:41 <br/> 1:19', 'STOP', 'VISITOR TIMEOUT', 'C C C R L D', 'C C L D D G']
# ['284', '3', 'EV', '18:41 <br/> 1:19', 'PENL', 'STL #17 SCHWARTZ\xa0Hooking(2 min) Drawn By: DET #72 ATHANASIOU', 'C C C R L D', 'C C L D D G']
# ['285', '3', 'EV', '18:41 <br/> 1:19', 'PENL', 'DET #72 ATHANASIOU\xa0Embellishment(2 min), Off. Zone', 'C C C R L D', 'C L D D G']
# ['286', '3', 'EV', '18:41 <br/> 1:19', 'FAC', 'DET won Off. Zone - DET #40 ZETTERBERG vs STL #71 SOBOTKA', 'C C R L D', 'C C D D G']
# ['287', '3', 'EV', '18:56 <br/> 1:04', 'MISS', 'DET #14 NYQUIST, Wrist, Wide of Net, Off. Zone, 37 ft.', 'C C R L D', 'C C D D G']
# ['288', '3', 'EV', '19:14 <br/> 0:46', 'SHOT', 'DET ONGOAL - #39 MANTHA, Wrist, Off. Zone, 36 ft.', 'C C R L D', 'C C D D G']
# ['289', '3', 'EV', '19:25 <br/> 0:35', 'BLOCK', 'DET #14 NYQUIST BLOCKED BY  STL #19 BOUWMEESTER, Wrist, Def. Zone', 'C C R L D', 'C C D D G']
# ['290', '3', 'EV', '19:33 <br/> 0:27', 'BLOCK', 'STL #71 SOBOTKA BLOCKED BY  DET #55 KRONWALL, Wrist, Def. Zone', 'C C R L D', 'C L D D G']
# ['291', '3', 'EV', '19:55 <br/> 0:05', 'MISS', 'DET #8 ABDELKADER, Tip-In, Wide of Net, Off. Zone, 10 ft.', 'C C R L D', 'R L D D G']
# ['292', '3', 'EV', '19:57 <br/> 0:03', 'PENL', 'STL #40 HUTTON\xa0Slashing(2 min) Served By: #9 UPSHALL, Def. Zone Drawn By: DET #8 ABDELKADER', 'C C R L D', 'R L D D G']
# ['293', '3', 'EV', '19:57 <br/> 0:03', 'PENL', 'DET #8 ABDELKADER\xa0Interference on goalkeeper(2 min), Off. Zone Drawn By: STL #40 HUTTON', 'C C R L D', 'C L D D G']
# ['294', '3', 'EV', '19:57 <br/> 0:03', 'FAC', 'DET won Off. Zone - DET #51 NIELSEN vs STL #10 SCHENN', 'C C R R L', 'C L D D G']
# ['295', '3', '', '20:00 <br/> 0:00', 'PEND', 'Period End- Local time: 9:40 CST', 'C C R R L', 'C L D D G']
# ['296', '3', '', '20:00 <br/> 0:00', 'GEND', 'Game End- Local time: 9:40 CST', '', '']

# %%
def get_game_df(
    soup,
    local_html=True,
) -> pd.DataFrame:
    '''
    Returns the parsed HTML stats table for some game and returns
    a DataFrame.
    
    local_html : bool
        Set True if using local HTML file. Otherwise set False
        for requested HTML from nhl.com
    '''

    if not local_html:
        raise NotImplementedError('Only local HTML supported')

    # Parse the main table
    data = []
    for row in soup.find_all('tr', {'class': 'evenColor'}):
        d = []
        for i, row_data in enumerate(row.find_all('td')):
            if 'class' in row_data.attrs:
                classes = ' '.join(row_data.attrs['class'])
                if 'bborder' not in classes:
                    continue
            else:
                continue

            if i == 3:
                # Parse the time
                row_data_text = ' '.join([str(s) for s in row_data.contents])

            elif i >= 6:
                # Parse the players on ice
                row_data_text = ' '.join(re.findall('[a-zA-Z]+', row_data.text.strip()))

            else:
                # Standard parse
                row_data_text = row_data.text.strip()
                
            d.append(row_data_text)

        if len(d) >= 8:
            data.append(d[:8])
    
    cols = ['#', 'per', 'type', 'time', 'event', 'description', 'visitor_on_ice', 'home_on_ice']
    df = pd.DataFrame(data, columns=cols)
    
    good_rows = df['#'].apply(is_int)
    df = df.loc[good_rows]
    df['#'] = df['#'].astype(int)
    df['per'] = df['per'].astype(int)
    df['time'] = parse_time(df['time'])
#     df['team'] = parse_team(df['description'])
    
    # Get the team info
    team_names = []
    for row_data in soup.find_all('td', {'class': 'heading + bborder'}):
        if 'on ice' in row_data.text.lower():
            team_names.append(row_data.text.split()[0])
        if len(team_names) == 2:
            break
    if len(team_names) != 2:
        team_names = ['', '']
    team_info = {'visitor': team_names[0], 'home': team_names[1]}
    
    return df, team_info

df, team_info = get_game_df(soup)

# %%
(df['description'] + '.').str.split().apply(lambda x: x[0])
# Out:
# 0            .
# 1            .
# 2            .
# 3       Period
# 4          STL
# 5         PUCK
# 6          STL
# 7         PUCK
# 8          DET
# 9          STL
# 10         DET
# 11         DET
# 12      GOALIE
# 13         STL
# 14        HAND
# 15         DET
# 16         STL
# 17         DET
# 18         STL
# 19         STL
# 20         STL
# 21         DET
# 22         STL
# 23      ICING.
# 24         DET
# 25         DET
# 26         DET
# 27         DET
# 28      GOALIE
# 29         STL
#         ...
# 266     GOALIE
# 267        DET
# 268        DET
# 269       PUCK
# 270        DET
# 271        DET
# 272        DET
# 273        DET
# 274     GOALIE
# 275        STL
# 276        DET
# 277        DET
# 278        DET
# 279        DET
# 280        DET
# 281        STL
# 282    VISITOR
# 283        STL
# 284        DET
# 285        DET
# 286        DET
# 287        DET
# 288        DET
# 289        STL
# 290        DET
# 291        STL
# 292        DET
# 293        DET
# 294     Period
# 295       Game
# Name: description, Length: 296, dtype: object

# %%
def goalie_pull_game_search(
    game_df: pd.DataFrame,
    team_info: dict,
    verbose=False,
) -> list:
    '''
    Search through a DataFrame stats table for goalie pulls, and
    finds empty net goals / games that end with a goalie pulled.
    
    team_info : dict
        Visitor and away team names.
    '''
    out = []
    pull_threshold = datetime.timedelta(minutes=15)

    o = {}
    prev_row = None
    prev_row_players = ['', '']
    pull_team = ''
    pull_switch = False
    goal_switch = False
    
    i_final_row = game_df.index[-1]

    for i, row in game_df.iterrows():
        if verbose:
            print(f'Looking at row {i}, # = {row["#"]}')
        if prev_row is None:
            prev_row = row.copy()
                 
        visitor_g_pull = 'G' not in row.visitor_on_ice
        home_g_pull = 'G' not in row.home_on_ice
        if visitor_g_pull or home_g_pull:
            if not pull_switch:
                # The goalie was just pulled
                pull_switch = True
                o = {}
                if visitor_g_pull:
                    pull_team = 'visitor'
                elif home_g_pull:
                    pull_team = 'home'
                else:
                    raise ValueError('Home or away team must have goalie pulled')
                o['team_name'] = team_info.get(pull_team, '')
                o['pull_period'] = row.per
                o['pull_time'] = (row.time + prev_row.time) / 2
                if verbose:
                    print(f'team, period, time = \n{o}')

        if i == i_final_row:
            # Check if game ended 5 on 6
            if o:
                print(Fore.RED + f'Game end with no goalie in net!' + Style.RESET_ALL)
                o['game_end_time'] = row.time
                out.append(o.copy())
                  
        # Search for an event (goal for / against / end of game)
        if pull_switch:
            print('Searching for a goal or end of game')
            if row.event.lower() == 'goal':
                print(f'Found goal after a pull, setting goal against time as {row.time}')
                if row.team == o['team_name']:
                    o['goal_for_time'] = row.time
                else:
                    o['goal_against_time'] = row.time
                  
                if row.time == o['pull_time']:
                    print(f'Goal time equal to pull time {row.time}. '
                          'Ignoring it and searching again.')
                    continue
                
                if ((pull_team == 'visitor' and visitor_g_pull)
                    or (pull_team == 'home' and home_g_pull)):
                    # It's a true empty net goal
                    print(Fore.RED + f'Found empty net goal:\n{o}' + Style.RESET_ALL)
                    out.append(o.copy())
                else:
                    print('Goalie was back in the net')
                    pass
                o = {}
                pull_switch = False

        prev_row = row.copy()

    return out

# %%
pulls = goalie_pull_game_search(df, team_info, verbose=True)

# %%
pulls

# %%
center_el = soup.find_all('table', {'id': 'GameInfo'})[0]

# %%
center_el

# %%
game_number = center_el.find_all('tr')[6].text.split()[-1].lstrip('0')

# %%
game_number

# %%
date = center_el.find_all('tr')[3].text.strip()

# %%
date

# %%
def get_game_meta(soup) -> dict:
    '''
    Get game metadata like the date and game number.
    '''
    try:
        center_el = soup.find_all('table', {'id': 'GameInfo'})[0]
        game_number = center_el.find_all('tr')[6].text.split()[-1].lstrip('0')
        date = center_el.find_all('tr')[3].text.strip()
        return {'game_number': game_number, 'date': date}
    except:
        print('Failed to get meta data :(')
        return {}
    
get_game_meta(soup)

# %%
def parse_game(
    soup: BeautifulSoup,
    cols: list = None,
    season='',
    verbose=False
) -> list:
    '''
    Search for empty net goals for, against and game ends,
    for a given game. Input the HTML as a BeautifulSoup object.
    '''
    out = []
                  
    # Default columns
    if cols is None:
        cols = [
            'season',
            'game_number',
            'team_name',
            'date',
            'pull_period',
            'pull_time',
            'goal_for_time',
            'goal_against_time',
            'game_end_time',
            'goal_for_timedelta',
            'goal_against_timedelta',
            'game_end_timedelta',
        ]

    # Get the game stats df    
    game_df, team_info = get_game_df(soup)
    
    # Get the game metadata
    meta_data = get_game_meta(soup)
    if season:
        meta_data['season'] = season
                  
    # Check for goalie pulls
    visitor_goalie_pull_idx = ~(game_df.visitor_on_ice.str.contains('G'))
    home_goalie_pull_idx = ~(game_df.home_on_ice.str.contains('G'))
    if not (visitor_goalie_pull_idx.sum() + home_goalie_pull_idx.sum()):
        return []    
    
    # For each goalie pull, determine the outcome
    game_5on6_data = goalie_pull_game_search(
        game_df, team_info, verbose=verbose
    )
    
    if not game_5on6_data:
        return []
    
    out = []
    for row in game_5on6_data:
        row.update(meta_data)
        out.append([row.get(col, float('nan')) for col in cols])

    return out


def make_final_df(
    data: list,
    cols: list,
) -> pd.DataFrame:
    '''
    Return table with columns:
     - season
     - game number
     - team name
     - date
     - period of pull
     - time of pull
     - time of goal for
     - time of goal against
     - time of goal end
     - timedelta of goal for (since pull)
     - timedelta of goal against (since pull)
     - timedelta of game end (since pull)
     
    Each row represents a goalie pull event.
    Goalie pull events that don't result in
    one of the above are ignored.
    '''
    df = pd.DataFrame(data, columns=cols)
    df['date'] = parse_date(df.date.fillna('').astype(str))
    df['goal_for_timedelta'] = goalie_pull_timedelta(df.goal_for_time, df.pull_time)
    df['goal_against_timedelta'] = goalie_pull_timedelta(df.goal_against_time, df.pull_time)
    df['game_end_timedelta'] = goalie_pull_timedelta(df.game_end_time, df.pull_time)
    
    return df

# %%
def parse_game_range(
    seasons: list,
    test: bool = False,
) -> pd.DataFrame:
    '''
    Parse every game for a given season.
    
    Folder structure is:
    ../data/raw/html/{season}/{game_number}.html
    
    '''
    
    root_data_path = '../../data/raw/html'
    if not os.path.exists(root_data_path):
        print(f'Root data path not found ({root_data_path})')
        return None
    
    cols = [
        'season',
        'game_number',
        'team_name',
        'date',
        'pull_period',
        'pull_time',
        'goal_for_time',
        'goal_against_time',
        'game_end_time',
        'goal_for_timedelta',
        'goal_against_timedelta',
        'game_end_timedelta',
    ]    
    data = []
    for season in seasons:        
        search_string = os.path.join(root_data_path, season, '*.html')
        html_files = glob.glob(search_string)
        print(f'Found {len(html_files)} files')
        i = 0
        for file in tqdm_notebook(html_files):
            i += 1
            if test:
                return_condition = i%20 == 0
                if return_condition: 
                    print(f'Testing mode - stopping script at {return_condition}')
                    return data, make_final_df(data, cols)
            
            print(f'Processing file {file}')
            try:
                with open(file, 'r') as f:
                    page_text = f.read()
                    soup = BeautifulSoup(page_text, 'lxml')
            except Exception as e:
                print(f'Unable to read/parse file {file}')
                print(str(e))
                continue
            
            try:
                d = parse_game(soup, cols, season)
                if not d:
                    continue
            except Exception as e:
                print(f'Unable to parse game for file {file}')
                print(str(e))
                continue

            data += d
            
    df = make_final_df(data, cols)
    return df

# %%
def test_parse_game_range(season, game_number):
    '''
    Parse a specific game with verbose output.
    '''
    
    cols = [
        'season',
        'game_number',
        'team_name',
        'date',
        'pull_period',
        'pull_time',
        'goal_for_time',
        'goal_against_time',
        'game_end_time',
        'goal_for_timedelta',
        'goal_against_timedelta',
        'game_end_timedelta',
    ]    
    data = []
    
    file = f'../../data/raw/html/{season}/{game_number}.html'
    print(f'Processing file {file}')
    with open(file, 'r') as f:
        try:
            page_text = f.read()
            soup = BeautifulSoup(page_text, 'lxml')
        except Exception as e:
            print(f'Unable to read/parse file {file}')
            raise e

    try:
        d = parse_game(soup, cols, season, verbose=True)
        if not d:
            print('No return from parse_game')
    except Exception as e:
        print(f'Unable to parse game for file {file}')
        raise e

    data = d
    df = make_final_df(data, cols)
    return df

# %%
test_parse_game_range('20072008', 980)
# Out:
# Processing file ../../data/raw/html/20072008/980.html
# Looking at row 0, # = 1
# Looking at row 1, # = 2
# Looking at row 2, # = 3
# Looking at row 3, # = 4
# Looking at row 4, # = 5
# Looking at row 5, # = 6
# Looking at row 6, # = 7
# Looking at row 7, # = 8
# Looking at row 8, # = 9
# Looking at row 9, # = 10
# Looking at row 10, # = 11
# Looking at row 11, # = 12
# Looking at row 12, # = 13
# Looking at row 13, # = 14
# Looking at row 14, # = 15
# Looking at row 15, # = 16
# Looking at row 16, # = 17
# Looking at row 17, # = 18
# Looking at row 18, # = 19
# Looking at row 19, # = 20
# Looking at row 20, # = 21
# Looking at row 21, # = 22
# Looking at row 22, # = 23
# Looking at row 23, # = 24
# Looking at row 24, # = 25
# Looking at row 25, # = 26
# Looking at row 26, # = 27
# Looking at row 27, # = 28
# Looking at row 28, # = 29
# Looking at row 29, # = 30
# Looking at row 30, # = 31
# Looking at row 31, # = 32
# Looking at row 32, # = 33
# Looking at row 33, # = 34
# Looking at row 34, # = 35
# Looking at row 35, # = 36
# Looking at row 36, # = 37
# Looking at row 37, # = 38
# Looking at row 38, # = 39
# Looking at row 39, # = 40
# Looking at row 40, # = 41
# Looking at row 41, # = 42
# Looking at row 42, # = 43
# Looking at row 43, # = 44
# Looking at row 44, # = 45
# Looking at row 45, # = 46
# Looking at row 46, # = 47
# Looking at row 47, # = 48
# Looking at row 48, # = 49
# Looking at row 49, # = 50
# Looking at row 50, # = 51
# Looking at row 51, # = 52
# Looking at row 52, # = 53
# Looking at row 53, # = 54
# Looking at row 54, # = 55
# Looking at row 55, # = 56
# Looking at row 56, # = 57
# Looking at row 57, # = 58
# Looking at row 58, # = 59
# Looking at row 59, # = 60
# Looking at row 60, # = 61
# Looking at row 61, # = 62
# Looking at row 62, # = 63
# Looking at row 63, # = 64
# Looking at row 64, # = 65
# Looking at row 65, # = 66
# Looking at row 66, # = 67
# Looking at row 67, # = 68
# Looking at row 68, # = 69
# Looking at row 69, # = 70
# Looking at row 70, # = 71
# Looking at row 71, # = 72
# Looking at row 72, # = 73
# Looking at row 73, # = 74
# Looking at row 74, # = 75
# Looking at row 75, # = 76
# Looking at row 76, # = 77
# Looking at row 77, # = 78
# Looking at row 272, # = 273
# Searching for a goal or end of game
# Looking at row 273, # = 274
# Searching for a goal or end of game
# Looking at row 274, # = 275
# Searching for a goal or end of game
# Looking at row 275, # = 276
# Searching for a goal or end of game
# Looking at row 276, # = 277
# Searching for a goal or end of game
# Looking at row 277, # = 278
# Searching for a goal or end of game
# Looking at row 278, # = 279
# Searching for a goal or end of game
# Looking at row 279, # = 280
# Searching for a goal or end of game
# Looking at row 280, # = 281
# Searching for a goal or end of game
# Looking at row 281, # = 282
# Searching for a goal or end of game
# Looking at row 282, # = 283
# Searching for a goal or end of game
# Looking at row 283, # = 284
# Searching for a goal or end of game
# Looking at row 284, # = 285
# Searching for a goal or end of game
# Looking at row 285, # = 286
# Searching for a goal or end of game
# Looking at row 286, # = 287
# Searching for a goal or end of game
# Looking at row 287, # = 288
# Searching for a goal or end of game
# Looking at row 288, # = 289
# Searching for a goal or end of game
# Looking at row 289, # = 290
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:14:06
# Goalie was back in the net
# Looking at row 290, # = 291
# Looking at row 291, # = 292
# Looking at row 292, # = 293
# Looking at row 293, # = 294
# Looking at row 294, # = 295
# Looking at row 295, # = 296
# Looking at row 296, # = 297
# Looking at row 297, # = 298
# Looking at row 298, # = 299
# Looking at row 299, # = 300
# Looking at row 300, # = 301
# Looking at row 301, # = 302
# Looking at row 302, # = 303
# Looking at row 303, # = 304
# Looking at row 304, # = 305
# Looking at row 305, # = 306
# Looking at row 306, # = 307
# Looking at row 307, # = 308
# Looking at row 308, # = 309
# Looking at row 309, # = 310
# Looking at row 310, # = 311
# Looking at row 311, # = 312
# Looking at row 312, # = 313
# Looking at row 313, # = 314
# Looking at row 314, # = 315
# Looking at row 315, # = 316
# Looking at row 316, # = 317
# team, period, time =
# {'team_name': 'PIT', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:56')}
# Searching for a goal or end of game
# Looking at row 317, # = 318
# Searching for a goal or end of game
# Looking at row 318, # = 319
# Searching for a goal or end of game
# Looking at row 319, # = 320
# Searching for a goal or end of game
# Looking at row 320, # = 321
# Searching for a goal or end of game
# Looking at row 321, # = 322
# Searching for a goal or end of game
# Looking at row 322, # = 323
# Searching for a goal or end of game
# Looking at row 323, # = 324
# Searching for a goal or end of game
# Looking at row 324, # = 325
# Searching for a goal or end of game
# Looking at row 325, # = 326
# Game end with no goalie in net!
# Searching for a goal or end of game
#      season game_number team_name       date  pull_period pull_time  \
# 0  20072008         980       PIT 2008-03-01            3  00:18:56
#
#    goal_for_time  goal_against_time game_end_time  goal_for_timedelta  \
# 0            NaN                NaN      00:20:00                 NaN
#
#    goal_against_timedelta game_end_timedelta
# 0                     NaN           00:01:04

# %%
seasons = ['20032004']

data, df_goalie_pull = parse_game_range(seasons, test=True)
# Out:
# Found 1230 files
# HBox(children=(IntProgress(value=0, max=1230), HTML(value='')))
# Processing file ../data/html/20032004/340.html
# Processing file ../data/html/20032004/710.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:44
# Goal time equal to pull time 0 days 00:19:44. Ignoring it and searching for .
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:47
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:44'), 'goal_against_time': Timedelta('0 days 00:19:47')}
# Processing file ../data/html/20032004/205.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1230.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:40
# Found empty net goal:
# {'team_name': 'S.J', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:39'), 'goal_for_time': Timedelta('0 days 00:19:40')}
# Processing file ../data/html/20032004/655.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:25
# Found empty net goal:
# {'team_name': 'PHX', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:03'), 'goal_against_time': Timedelta('0 days 00:19:25')}
# Processing file ../data/html/20032004/985.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:44
# Found empty net goal:
# {'team_name': 'PHX', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:34'), 'goal_for_time': Timedelta('0 days 00:18:44')}
# Processing file ../data/html/20032004/74.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/74.html
# 'time'
# Processing file ../data/html/20032004/1119.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:17
# Found empty net goal:
# {'team_name': 'ATL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:29'), 'goal_for_time': Timedelta('0 days 00:19:17')}
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/439.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/593.html
# Processing file ../data/html/20032004/747.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/317.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/602.html
# Processing file ../data/html/20032004/252.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/481.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/878.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/23.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/897.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:41
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:28'), 'goal_against_time': Timedelta('0 days 00:19:41')}
# Processing file ../data/html/20032004/194.html
# Testing mode - stopping script at True

# %%
df_goalie_pull
# Out:
#       season game_number team_name       date  pull_period pull_time  \
# 0   20032004         710       CHI 2004-01-21            3  00:19:44
# 1   20032004         205       MIN 2003-11-08            3  00:19:58
# 2   20032004        1230       S.J 2004-04-04            3  00:18:39
# 3   20032004         655       PHX 2004-01-13            3  00:19:03
# 4   20032004         985       PHX 2004-03-02            3  00:18:34
# 5   20032004        1119       ATL 2004-03-20            3  00:18:29
# 6   20032004         439       L.A 2003-12-13            3  00:18:45
# 7   20032004         317       EDM 2003-11-26            3  00:17:48
# 8   20032004         481       NYR 2003-12-20            3  00:19:11
# 9   20032004         878       COL 2004-02-16            3  00:18:39
# 10  20032004          23       CAR 2003-10-11            3  00:18:57
# 11  20032004         897       CHI 2004-02-19            3  00:19:28
#
#    goal_for_time goal_against_time game_end_time goal_for_timedelta  \
# 0            NaT          00:19:47           NaT                NaT
# 1            NaT               NaT      00:19:58                NaT
# 2       00:19:40               NaT           NaT           00:01:01
# 3            NaT          00:19:25           NaT                NaT
# 4       00:18:44               NaT           NaT           00:00:10
# 5       00:19:17               NaT           NaT           00:00:48
# 6            NaT               NaT      00:19:58                NaT
# 7            NaT               NaT      00:19:58                NaT
# 8            NaT               NaT      00:19:52                NaT
# 9            NaT               NaT      00:19:44                NaT
# 10           NaT               NaT      00:19:39                NaT
# 11           NaT          00:19:41           NaT                NaT
#
#    goal_against_timedelta game_end_timedelta
# 0                00:00:03                NaT
# 1                     NaT           00:00:00
# 2                     NaT                NaT
# 3                00:00:22                NaT
# 4                     NaT                NaT
# 5                     NaT                NaT
# 6                     NaT           00:01:13
# 7                     NaT           00:02:10
# 8                     NaT           00:00:41
# 9                     NaT           00:01:05
# 10                    NaT           00:00:42
# 11               00:00:13                NaT

# %%
df_goalie_pull = parse_game_range(seasons)
# Out:
# Found 1230 files
# HBox(children=(IntProgress(value=0, max=1230), HTML(value='')))
# Processing file ../data/html/20032004/340.html
# Processing file ../data/html/20032004/710.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:44
# Goal time equal to pull time 0 days 00:19:44. Ignoring it and searching for .
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:47
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:44'), 'goal_against_time': Timedelta('0 days 00:19:47')}
# Processing file ../data/html/20032004/205.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1230.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:40
# Found empty net goal:
# {'team_name': 'S.J', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:39'), 'goal_for_time': Timedelta('0 days 00:19:40')}
# Processing file ../data/html/20032004/655.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:25
# Found empty net goal:
# {'team_name': 'PHX', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:03'), 'goal_against_time': Timedelta('0 days 00:19:25')}
# Processing file ../data/html/20032004/985.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:44
# Found empty net goal:
# {'team_name': 'PHX', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:34'), 'goal_for_time': Timedelta('0 days 00:18:44')}
# Processing file ../data/html/20032004/74.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/74.html
# 'time'
# Processing file ../data/html/20032004/1119.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:17
# Found empty net goal:
# {'team_name': 'ATL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:29'), 'goal_for_time': Timedelta('0 days 00:19:17')}
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/439.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/593.html
# Processing file ../data/html/20032004/747.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/317.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/602.html
# Processing file ../data/html/20032004/252.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/481.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/878.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/23.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/897.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:41
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:28'), 'goal_against_time': Timedelta('0 days 00:19:41')}
# Processing file ../data/html/20032004/194.html
# Processing file ../data/html/20032004/301.html
# Processing file ../data/html/20032004/751.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/244.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/614.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/614.html
# 'time'
# Processing file ../data/html/20032004/35.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1158.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:17:52
# Goalie was back in the net
# Processing file ../data/html/20032004/497.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/182.html
# Processing file ../data/html/20032004/478.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/881.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/706.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/356.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:28
# Found empty net goal:
# {'team_name': 'ANA', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:31'), 'goal_for_time': Timedelta('0 days 00:19:28')}
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/643.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1226.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:29
# Found empty net goal:
# {'team_name': 'STL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:53'), 'goal_against_time': Timedelta('0 days 00:19:29')}
# Processing file ../data/html/20032004/213.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/839.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/62.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/993.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/9.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/585.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/638.html
# Processing file ../data/html/20032004/792.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/268.html
# Processing file ../data/html/20032004/287.html
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/907.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:59
# Goal time equal to pull time 0 days 00:18:59. Ignoring it and searching for .
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1031.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:47
# Found empty net goal:
# {'team_name': 'N.J', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:53'), 'goal_against_time': Timedelta('0 days 00:19:47')}
# Processing file ../data/html/20032004/454.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1174.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/141.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/511.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/842.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:44
# Found empty net goal:
# {'team_name': 'MTL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:00'), 'goal_against_time': Timedelta('0 days 00:19:44')}
# Processing file ../data/html/20032004/19.html
# Processing file ../data/html/20032004/395.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/680.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/403.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:01
# Found empty net goal:
# {'team_name': 'WSH', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:38'), 'goal_against_time': Timedelta('0 days 00:19:01')}
# Processing file ../data/html/20032004/1066.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/950.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/815.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/815.html
# 'time'
# Processing file ../data/html/20032004/1089.html
# Processing file ../data/html/20032004/546.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:38
# Found empty net goal:
# {'team_name': 'NYR', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:01'), 'goal_for_time': Timedelta('0 days 00:18:38')}
# Processing file ../data/html/20032004/116.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:01
# Found empty net goal:
# {'team_name': 'COL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:50'), 'goal_against_time': Timedelta('0 days 00:19:01')}
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1123.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/383.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/679.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/229.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/696.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/946.html
# Processing file ../data/html/20032004/1070.html
# Processing file ../data/html/20032004/415.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1135.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/100.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/550.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/803.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/58.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/784.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/291.html
# Processing file ../data/html/20032004/442.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1027.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/911.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/854.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/507.html
# Processing file ../data/html/20032004/157.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1162.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1115.html
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/120.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/570.html
# Processing file ../data/html/20032004/823.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/78.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/989.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/966.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/97.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1050.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/435.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/659.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/209.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/874.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/527.html
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/177.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1142.html
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/198.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/462.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1007.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/931.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:30
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:08'), 'goal_against_time': Timedelta('0 days 00:19:30')}
# Processing file ../data/html/20032004/1154.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:28
# Found empty net goal:
# {'team_name': 'COL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:24'), 'goal_against_time': Timedelta('0 days 00:18:28')}
# Processing file ../data/html/20032004/161.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/531.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/862.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/39.html
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/927.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1011.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:38
# Found empty net goal:
# {'team_name': 'NSH', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:53'), 'goal_against_time': Timedelta('0 days 00:19:38')}
# Processing file ../data/html/20032004/474.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/618.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/248.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/835.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/566.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:17:40
# Goalie was back in the net
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:43
# Found empty net goal:
# {'team_name': 'NYR', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:41'), 'goal_for_time': Timedelta('0 days 00:19:43')}
# Processing file ../data/html/20032004/136.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1103.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:43
# Found empty net goal:
# {'team_name': 'CBJ', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:57'), 'goal_against_time': Timedelta('0 days 00:19:43')}
# Processing file ../data/html/20032004/423.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/589.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1046.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:55
# Found empty net goal:
# {'team_name': 'CBJ', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:28'), 'goal_against_time': Timedelta('0 days 00:19:55')}
# Processing file ../data/html/20032004/81.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/5.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/970.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/458.html
# Processing file ../data/html/20032004/1197.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/15.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1178.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/264.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/634.html
# Processing file ../data/html/20032004/321.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/771.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1085.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/819.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:17:51
# Found empty net goal:
# {'team_name': 'NSH', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:17:17'), 'goal_against_time': Timedelta('0 days 00:17:51')}
# Processing file ../data/html/20032004/42.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/399.html
# Processing file ../data/html/20032004/663.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1206.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/233.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/726.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/376.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:49
# Found empty net goal:
# {'team_name': 'VAN', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:29'), 'goal_against_time': Timedelta('0 days 00:19:49')}
# Processing file ../data/html/20032004/419.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:55
# Found empty net goal:
# {'team_name': 'NSH', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:13'), 'goal_against_time': Timedelta('0 days 00:19:55')}
# Processing file ../data/html/20032004/54.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:07
# Found empty net goal:
# {'team_name': 'ANA', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:00'), 'goal_against_time': Timedelta('0 days 00:18:07')}
# Processing file ../data/html/20032004/1093.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1139.html
# Processing file ../data/html/20032004/225.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1210.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/675.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/360.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:38
# Found empty net goal:
# {'team_name': 'L.A', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:11'), 'goal_against_time': Timedelta('0 days 00:18:38')}
# Processing file ../data/html/20032004/730.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/730.html
# 'time'
# Processing file ../data/html/20032004/1181.html
# Processing file ../data/html/20032004/858.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:58
# Found empty net goal:
# {'team_name': 'MTL', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:04'), 'goal_against_time': Timedelta('0 days 00:18:58')}
# Processing file ../data/html/20032004/622.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/788.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/272.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/767.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/337.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/623.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/789.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:50
# Found empty net goal:
# {'team_name': 'L.A', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:20'), 'goal_for_time': Timedelta('0 days 00:18:50')}
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:54
# ...
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/36.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/640.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1225.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/210.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/705.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:09
# Found empty net goal:
# {'team_name': 'CGY', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:17:59'), 'goal_against_time': Timedelta('0 days 00:19:09')}
# Processing file ../data/html/20032004/355.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1049.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:59
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:08'), 'goal_against_time': Timedelta('0 days 00:19:59')}
# Processing file ../data/html/20032004/586.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:38
# Found empty net goal:
# {'team_name': 'L.A', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:54'), 'goal_for_time': Timedelta('0 days 00:19:38')}
# Processing file ../data/html/20032004/61.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/990.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:46
# Found empty net goal:
# {'team_name': 'CHI', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:23'), 'goal_against_time': Timedelta('0 days 00:19:46')}
# Processing file ../data/html/20032004/139.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/569.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/284.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:49
# Found empty net goal:
# {'team_name': 'L.A', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:49'), 'goal_against_time': Timedelta('0 days 00:19:49')}
# Processing file ../data/html/20032004/791.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/791.html
# 'time'
# Processing file ../data/html/20032004/841.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1177.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/142.html
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/512.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1032.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/1198.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:39
# Goal time equal to pull time 0 days 00:19:39. Ignoring it and searching for .
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/457.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:33
# Found empty net goal:
# {'team_name': 'EDM', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:38'), 'goal_against_time': Timedelta('0 days 00:19:33')}
# Processing file ../data/html/20032004/904.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/683.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/379.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/729.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:18:44
# Found empty net goal:
# {'team_name': 'BOS', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:27'), 'goal_for_time': Timedelta('0 days 00:18:44')}
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1209.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:42
# Found empty net goal:
# {'team_name': 'BUF', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:19:02'), 'goal_against_time': Timedelta('0 days 00:19:42')}
# Processing file ../data/html/20032004/396.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/545.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/115.html
# Processing file ../data/html/20032004/1120.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/816.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/953.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/400.html
# Processing file ../data/html/20032004/1065.html
# Processing file ../data/html/20032004/695.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/380.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/800.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1136.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/103.html
# Missing column: time
# Missing column: team
# Unable to parse game for file ../data/html/20032004/103.html
# 'time'
# Processing file ../data/html/20032004/553.html
# Processing file ../data/html/20032004/1073.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:14
# Found empty net goal:
# {'team_name': 'ANA', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:16:58'), 'goal_against_time': Timedelta('0 days 00:19:14')}
# Processing file ../data/html/20032004/416.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/945.html
# Processing file ../data/html/20032004/338.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/292.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/768.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/787.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/504.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/154.html
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/1161.html
# Processing file ../data/html/20032004/857.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Found goal after a pull, setting goal against time as 0 days 00:19:17
# Found empty net goal:
# {'team_name': 'TOR', 'pull_period': 3, 'pull_time': Timedelta('0 days 00:18:55'), 'goal_against_time': Timedelta('0 days 00:19:17')}
# Found goalie pull
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Searching for a goal or end of game
# Game end with no goalie in net!
# Searching for a goal or end of game
# Processing file ../data/html/20032004/912.html
# Found goalie pull
# Too early in game, not counting it
# Processing file ../data/html/20032004/441.html
# Processing file ../data/html/20032004/1024.html
# Found goalie pull
# Too early in game, not counting it
# Found goalie pull
# Too early in game, not counting it

# %%
df_goalie_pull
# Out:
#        season game_number team_name       date  pull_period pull_time  \
# 0    20032004         710       CHI 2004-01-21            3  00:19:44
# 1    20032004         205       MIN 2003-11-08            3  00:19:58
# 2    20032004        1230       S.J 2004-04-04            3  00:18:39
# 3    20032004         655       PHX 2004-01-13            3  00:19:03
# 4    20032004         985       PHX 2004-03-02            3  00:18:34
# 5    20032004        1119       ATL 2004-03-20            3  00:18:29
# 6    20032004         439       L.A 2003-12-13            3  00:18:45
# 7    20032004         317       EDM 2003-11-26            3  00:17:48
# 8    20032004         481       NYR 2003-12-20            3  00:19:11
# 9    20032004         878       COL 2004-02-16            3  00:18:39
# 10   20032004          23       CAR 2003-10-11            3  00:18:57
# 11   20032004         897       CHI 2004-02-19            3  00:19:28
# 12   20032004         751       TOR 2004-01-27            3  00:18:51
# 13   20032004         244       OTT 2003-11-15            3  00:19:00
# 14   20032004          35       VAN 2003-10-13            3  00:19:52
# 15   20032004         497       STL 2003-12-22            3  00:18:57
# 16   20032004         478       BOS 2003-12-20            3  00:19:25
# 17   20032004         706       WSH 2004-01-21            3  00:19:32
# 18   20032004         356       ANA 2003-12-02            3  00:18:31
# 19   20032004         356       ANA 2003-12-02            3  00:19:36
# 20   20032004         643       PHI 2004-01-12            3  00:19:20
# 21   20032004        1226       STL 2004-04-04            3  00:18:53
# 22   20032004         213       EDM 2003-11-11            3  00:19:37
# 23   20032004         839       PHX 2004-02-11            3  00:18:23
# 24   20032004          62       CBJ 2003-10-18            3  00:18:30
# 25   20032004         993       MIN 2004-03-03            3  00:19:17
# 26   20032004         585       CGY 2004-01-03            3  00:18:57
# 27   20032004         792       ANA 2004-02-01            3  00:18:20
# 28   20032004         287       BOS 2003-11-22            3  00:19:26
# 29   20032004         907       ATL 2004-02-21            3  00:19:14
# ..        ...         ...       ...        ...          ...       ...
# 696  20032004         210       NYR 2003-11-10            3  00:19:25
# 697  20032004         705       CGY 2004-01-20            3  00:17:59
# 698  20032004        1049       CHI 2004-03-11            3  00:19:08
# 699  20032004         586       L.A 2004-01-03            3  00:18:54
# 700  20032004         990       CHI 2004-03-03            3  00:19:23
# 701  20032004         139       PHI 2003-10-30            3  00:19:14
# 702  20032004         569       CAR 2004-01-02            3  00:18:39
# 703  20032004         284       L.A 2003-11-21            3  00:18:49
# 703           NaT          00:19:49           NaT                NaT
# 704           NaT               NaT      00:19:58                NaT
# 705           NaT               NaT      00:19:08                NaT
# 706           NaT          00:19:39      00:19:39                NaT
# 707           NaT          00:19:33           NaT                NaT
# 708           NaT               NaT      00:20:00                NaT
# 709           NaT               NaT      00:20:00                NaT
# 710           NaT               NaT      00:19:41                NaT
# 711      00:18:44               NaT           NaT           00:00:17
# 712           NaT               NaT      00:19:54                NaT
# 713           NaT          00:19:42           NaT                NaT
# 714           NaT               NaT      00:19:12                NaT
# 715           NaT               NaT      00:19:57                NaT
# 716           NaT               NaT      00:19:34                NaT
# 717           NaT               NaT      00:19:45                NaT
# 718           NaT          00:19:14           NaT                NaT
# 719           NaT               NaT      00:19:34                NaT
# 720           NaT               NaT      00:19:51                NaT
# 721           NaT               NaT      00:19:49                NaT
# 722           NaT               NaT      00:19:47                NaT
# 723           NaT               NaT      00:19:23                NaT
# 724           NaT          00:19:17           NaT                NaT
# 725           NaT               NaT      00:19:58                NaT
#
#     goal_against_timedelta game_end_timedelta
# 0                 00:00:03                NaT
# 1                      NaT           00:00:00
# 2                      NaT                NaT
# 3                 00:00:22                NaT
# 4                      NaT                NaT
# 5                      NaT                NaT
# 6                      NaT           00:01:13
# 7                      NaT           00:02:10
# 8                      NaT           00:00:41
# 9                      NaT           00:01:05
# 10                     NaT           00:00:42
# 11                00:00:13                NaT
# 12                     NaT           00:01:04
# 13                     NaT           00:00:54
# 14                     NaT           00:00:00
# 15                     NaT           00:01:02
# 16                     NaT           00:00:27
# 17                     NaT           00:00:00
# 18                     NaT                NaT
# 19                     NaT           00:00:06
# 20                     NaT           00:00:34
# 21                00:00:36                NaT
# 22                     NaT           00:00:00
# 23                     NaT           00:01:02
# 24                     NaT           00:01:30
# 25                     NaT           00:00:15
# 26                     NaT           00:01:00
# 27                     NaT           00:01:20
# 28                     NaT           00:00:00
# 29                     NaT           00:00:46
# ..                     ...                ...
# 696                    NaT           00:00:13
# 697               00:01:10                NaT
# 698               00:00:51                NaT
# 699                    NaT                NaT
# 700               00:00:23                NaT
# 701                    NaT           00:00:23
# 702                    NaT           00:01:12
# 703               00:01:00                NaT
# 704                    NaT           00:00:22
# 705                    NaT           00:00:00
# 706               00:00:00           00:00:00
# 707               00:00:55                NaT
# 708                    NaT           00:00:15
# 709                    NaT           00:00:53
# 710                    NaT           00:00:15
# 711                    NaT                NaT
# 712                    NaT           00:00:59
# 713               00:00:40                NaT
# 714                    NaT           00:00:10
# 715                    NaT           00:01:10
# 716                    NaT           00:00:00
# 717                    NaT           00:00:35
# 718               00:02:16                NaT
# 719                    NaT           00:00:14
# 720                    NaT           00:00:39
# 721                    NaT           00:00:41
# 722                    NaT           00:00:16
# 723                    NaT           00:01:32
# 724               00:00:22                NaT
# 725                    NaT           00:00:15
#
# [726 rows x 12 columns]

# %%
df_goalie_pull.to_csv('../data/csv/20032004_goalie_pulls_2019-02-13.csv', index=False)

# %%
df_goalie_pull.to_pickle('../data/pkl/20032004_goalie_pulls_2019-02-13.pkl')
